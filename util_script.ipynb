# %%
import pandas as pd
import numpy as np
import sqlite3
from urllib.parse import urlparse
from collections import defaultdict
# from adblockparser import AdblockRules

# %%
def get_base_script_url(script_url):
    script_url_no_param = script_url.split("?")[0].split("&")[0].split("#")[0]
    return script_url_no_param.split("://")[-1].strip()

def get_site(site_url):
    return site_url.split(".")[1]


CANVAS_READ_FUNCS = [
    "HTMLCanvasElement.toDataURL",
    "CanvasRenderingContext2D.getImageData"
    ]

CANVAS_WRITE_FUNCS = [
    "CanvasRenderingContext2D.fillText",
    "CanvasRenderingContext2D.strokeText"
    ]

CANVAS_FP_DO_NOT_CALL_LIST = ["CanvasRenderingContext2D.save",
                              "CanvasRenderingContext2D.restore",
                              "HTMLCanvasElement.addEventListener"]

WEBRTC_FP_CALLS = ["RTCPeerConnection.createDataChannel",
                   "RTCPeerConnection.createOffer"]

MIN_CANVAS_TEXT_LEN = 10
COOKIE_READ_IN_JS = "window.document.cookie"

# %%
query = """SELECT sv.site_url, sv.visit_id,
        js.script_url, js.operation, js.arguments, js.symbol, js.value
        FROM javascript as js LEFT JOIN site_visits as sv
        ON sv.visit_id = js.visit_id WHERE
        js.script_url <> ''
        """

# %%
exp_path = "exp-data/nyt-t1.sqlite"
conn = sqlite3.connect(exp_path)
js = pd.read_sql_query(query, conn)

# %%
def extract_host_from_url(url_ls):
    return list(map(lambda x: urlparse(x).netloc.split('.')[1] if len(urlparse(x).netloc.split('.')) > 1 else x, url_ls))

# %%
js["first_party_host"] = list(map(lambda x: get_site(x), js["site_url"]))

# %%
js["script_host"] = extract_host_from_url(js.script_url)

# %%
def is_third_party(primary_host, secondary_host):
    result = []
    for ph, sh in zip(primary_host, secondary_host):
        if ph == sh:
            result.append(False)
        else:
            result.append(True)
    return result

# %%
js['is_third_party'] = is_third_party(js.first_party_host, js.script_host)

# %%
def read_ab_rules_from_file(filename):
    filter_list = set()
    for l in open(filename):
        if len(l) == 0 or l[0] == '!':  # ignore these lines
            continue
        else:
            filter_list.add(l.strip())
    return filter_list

# %%
IMAGE_MIN_HEIGHT = 16
IMAGE_MIN_WIDTH = 16
def safe_int(string):
    """Convert string to int, return 0 if conversion fails."""
    try:
        return int(string)
    except ValueError:
        return 0

def image_is_too_small(arguments):
    if arguments is None:
        return True
    if safe_int(arguments[2]) < IMAGE_MIN_WIDTH or safe_int(arguments[3]) < IMAGE_MIN_HEIGHT:
        return True
    return False

def split_cookie_value(value):
    return set(map(lambda x: (x.split('=')[0].strip(), x.split('=')[1].strip()) if len(x.split('=')) > 1 else (x, None), value.split(';')))

# %%
third_party_js_script = js[js['is_third_party'] == True]

# %%
third_party_js_script_cookie_operations = third_party_js_script[third_party_js_script['symbol'].str.contains("window.document.cookie")]

# %%
third_party_set_cookie = defaultdict(set) # origin_host: (script_host, script_url, value)
third_party_get_cookie = defaultdict(set)

# %%
insignificant_cookie = 'Test|testWrite|test|lang|SameSite|Samesite|sameSite|samesite|expires|Path|path|domain|Expires|max-age'
insignificant_cookie_ls = insignificant_cookie.split('|')
for index, row in third_party_js_script_cookie_operations.iterrows():
    if row['value'] is None:
        continue
    if row["operation"] == "set":
        for cookie_name, cookie_value in split_cookie_value(row["value"]):
            if cookie_value == None or cookie_name in insignificant_cookie_ls:
                continue
            third_party_set_cookie[row['first_party_host']].add((row['script_host'], row['script_url'], cookie_name, cookie_value))
    elif row["operation"] == "get":
        for cookie_name, cookie_value in split_cookie_value(row["value"]):
            if cookie_value == None or cookie_name in insignificant_cookie_ls:
                continue
            third_party_get_cookie[row['first_party_host']].add((row['script_host'], row['script_url'], cookie_name, cookie_value))

# %%
def make_cookie_into_df(cookie_dict):
    first_party_ls = []
    script_host_ls = []
    script_url_ls = []
    cookie_name_ls = []
    cookie_value_ls = []
    for first_party, value_set in cookie_dict.items():
        first_party_ls.extend([first_party] * len(value_set))
        for script_host, script_url, cookie_name, cookie_value in value_set:
            script_host_ls.append(script_host)
            script_url_ls.append(script_url)
            cookie_name_ls.append(cookie_name)
            cookie_value_ls.append(cookie_value)
    return pd.DataFrame.from_dict({'origin_site':first_party_ls, 'script_host':script_host_ls, 'script_url': script_url_ls,\
                                   'cookie_name': cookie_name_ls, 'cookie_value': cookie_value_ls})

# %%
get_cookie_js = make_cookie_into_df(third_party_get_cookie)
set_cookie_js = make_cookie_into_df(third_party_set_cookie)

# %%
def drop_cookie_from_df(df):
    df.drop(df[df.script_host.apply(lambda x: len(x) < 5 and x != 'g')].index, \
                   inplace=True)
    df.drop(df[df.cookie_value.apply(lambda x: len(x) < 5)].index, inplace=True)

# %%
drop_cookie_from_df(get_cookie_js)

# %%
drop_cookie_from_df(set_cookie_js)

# %%
# canvas features
# sample check isin: df_new[df_new['l_ext'].isin([31, 22, 30, 25, 64])]
# third_party_js_image = third_party_js_script[third_party_js_script['symbol'].str.contains("CanvasRenderingContext2D.getImageData")

# %%
# third_party_img_trackers = defaultdict(set)
# for index, row in third_party_js_image.iterrows():
#     if image_is_too_small(row['arguments']):
#         third_party_img_trackers[row['first_party_host']].add((row['script_host'], row['script_url']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-3705fec053ee> in <module>()
#       1 third_party_img_trackers = defaultdict(set)
# ----> 2 for index, row in third_party_js_image.iterrows():
#       3     if image_is_too_small(row['arguments']):
#       4         third_party_img_trackers[row['first_party_host']].add((row['script_host'], row['script_url']))
#
# NameError: name 'third_party_js_image' is not defined

# %%
third_party_img_trackers
# Out:
# defaultdict(set,
#             {'mayoclinic': {('medtargetsystem',
#                'https://www.medtargetsystem.com/javascript/fp.js?5')}})

# %%
def get_base_script_url(script_url):
    script_url_no_param = script_url.split("?")[0].split("&")[0].split("#")[0]
    return script_url_no_param.split("://")[-1].strip()

# %%
MIN_FONT_FP_FONT_COUNT = 50
def canvas_font_fingerprinters(canvas_fonts, canvas_measure_text_calls):
    canvas_font_fingerprinting = defaultdict(set)
    for first_party_url, script_dict in canvas_fonts.items():
        for script_base_url, fonts_value in script_dict.items():
            if len(fonts_value) < MIN_FONT_FP_FONT_COUNT:
                continue
            for measure_url, args, call_count in canvas_measure_text_calls[first_party_url].items():
                if call_count > MIN_FONT_FP_FONT_COUNT and measure_url == script_base_url:
                    canvas_font_fingerprinting.add((first_party_url, script_base_url))
                    
    return canvas_font_fingerprinting

# %%
def convert_text(arguments):
    if not arguments:
        return ""
    return arguments[0].encode('ascii', 'ignore')

# %%
canvas_reads = defaultdict(set)
canvas_text = defaultdict(lambda: defaultdict(set))
canvas_write = defaultdict(lambda: defaultdict(set))
canvas_styles = defaultdict(lambda: defaultdict(set))
canvas_banned_calls = defaultdict(set)
canvas_fonts = defaultdict(lambda: defaultdict(set))
canvas_measure_text_calls = defaultdict(lambda: defaultdict(int))
webrtc_calls = defaultdict(lambda: defaultdict(set))
for index, row in third_party_js_script.iterrows():
    script_host = row.script_host
    base_script_url = get_base_script_url(row.script_url)
    if row.symbol in CANVAS_READ_FUNCS and row.operation == "call":
        if row.symbol == "CanvasRenderingContext2D.getImageData" and image_is_too_small(row['arguments']):
            continue
        canvas_reads[row.first_party_host].add((row.script_host, base_script_url))
    elif row.symbol in CANVAS_WRITE_FUNCS:
        text = convert_text(row.arguments)
        if len(text) >= MIN_CANVAS_TEXT_LEN:
            canvas_write[row.first_party_host][base_script_url].add(text)
    elif row.symbol == "CanvasRenderingContext2D.fillStyle" and row.operation == "set":
        if row.value != None:
            canvas_styles[row.first_party_host][base_script_url].add(row.value)
    elif row.operation == "call" and row.symbol in CANVAS_FP_DO_NOT_CALL_LIST:
        canvas_banned_calls[row.first_party_host].add((script_host, base_script_url))
    elif row.symbol == "CanvasRenderingContext2D.font" and row.operation == "set":
        canvas_fonts[row.first_party_host][base_script_url].add(row.value)
    elif row.symbol == "CanvasRenderingContext2D.measureText" and row.operation == "call":
        canvas_measure_text_calls[row.first_party_host][(base_script_url, row.arguments)] += 1
    elif (row.operation == "call" and row.symbol in WEBRTC_FP_CALLS) or\
                (row.operation == "set" and
                 row.symbol == "RTCPeerConnection.onicecandidate"):
        webrtc_calls[row.first_party_host][base_script_url].add(row.symbol)

# %%
def get_webrtc_fingerprinters(webrtc_calls):
    webrtc_fingerprinters = defaultdict(set)
    for first_host, script_dict in webrtc_calls.items():
        for script_url, sym_set in script_dict.items():
            if len(sym_set) == 3:
                webrtc_fingerprinters[first_host].add(script_url)
    return webrtc_fingerprinters

# %%
get_webrtc_fingerprinters(webrtc_calls)
canvas_font_fingerprinters(canvas_fonts, canvas_measure_text_calls)
# Out:
# defaultdict(set, {})

# %%
set(zip(js.script_url, js.is_third_party))[:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-e48c1809354a> in <module>()
# ----> 1 set(zip(js.script_url, js.is_third_party))[:5]
#
# TypeError: 'set' object is not subscriptable

# %%
set(js.script_url)
# Out:
# 191

# %%
set_cookie_js
# Out:
#     origin_site       script_host  \
# 0         webmd             liadm
# 1         webmd          adobedtm
# 2         webmd         amazonaws
# 5         webmd          adobedtm
# 6         webmd          adobedtm
# 7         webmd          adobedtm
# 8         webmd          adobedtm
# 9         webmd            criteo
# 10        webmd          adobedtm
# 12        webmd            criteo
# 13        webmd          adobedtm
# 14        webmd          adobedtm
# 15        webmd             media
# 16        webmd             media
# 19        webmd            stream
# 21        webmd            demdex
# 22        webmd             media
# 23        webmd          adobedtm
# 24        webmd         amazonaws
# 27        webmd             liadm
# 28        webmd          adobedtm
# 29        webmd             liadm
# 30        webmd          adobedtm
# 31        webmd             liadm
# 32        webmd         amazonaws
# 35        webmd         amazonaws
# 41        webmd             liadm
# 43        webmd          adobedtm
# 44        webmd          adobedtm
# 47        webmd             liadm
# ..          ...               ...
# 108  mayoclinic     siteintercept
# 109  mayoclinic         ensighten
# 111  mayoclinic         ensighten
# 112  mayoclinic  google-analytics
# 113  mayoclinic    rubiconproject
# 116  mayoclinic   medtargetsystem
# 118  mayoclinic         ensighten
# 119  mayoclinic    rubiconproject
# 121  mayoclinic         ensighten
# 122  mayoclinic     siteintercept
# 123  mayoclinic     siteintercept
# 125  mayoclinic  google-analytics
# 127  mayoclinic     siteintercept
# 131  mayoclinic  google-analytics
# 133  mayoclinic   medtargetsystem
# 139  mayoclinic    rubiconproject
# 140  mayoclinic   medtargetsystem
# 142     nytimes           gstatic
# 143     nytimes             media
# 146     nytimes    rubiconproject
# 147     nytimes    rubiconproject
# 148     nytimes  googletagmanager
# 150     nytimes            criteo
# 152     nytimes         iteratehq
# 153     nytimes         chartbeat
# 157     nytimes  google-analytics
# 163     nytimes            criteo
# 164     nytimes  google-analytics
# 165     nytimes         chartbeat
# 166     nytimes          pubmatic
#
#                                             script_url  \
# 0           https://b-code.liadm.com/sync-container.js
# 1    https://assets.adobedtm.com/extensions/EP5e9ec...
# 2          https://s3.amazonaws.com/ki.js/38969/hrI.js
# 5    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 6    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 7    https://assets.adobedtm.com/extensions/EP5e9ec...
# 8    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 9    https://gum.criteo.com/sync?r=2&c=321&j=window...
# 10   https://assets.adobedtm.com/extensions/EP5e9ec...
# 12   https://gum.criteo.com/sync?r=2&c=321&j=window...
# 13   https://assets.adobedtm.com/extensions/EP5e9ec...
# 14   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 15   https://contextual.media.net/bidexchange.js?ci...
# 16   https://contextual.media.net/bidexchange.js?ci...
# 19   https://ibclick.stream/assets/js/track/dist/js...
# 21   https://webmd.demdex.net/dest5.html?d_nsid=0#h...
# 22   https://contextual.media.net/bidexchange.js?ci...
# 23   https://assets.adobedtm.com/extensions/EP5e9ec...
# 24         https://s3.amazonaws.com/ki.js/38969/hrI.js
# 27          https://b-code.liadm.com/sync-container.js
# 28   https://assets.adobedtm.com/extensions/EP5e9ec...
# 29              https://b-code.liadm.com/a-00xm.min.js
# 30   https://assets.adobedtm.com/extensions/EP5e9ec...
# 31          https://b-code.liadm.com/sync-container.js
# 32         https://s3.amazonaws.com/ki.js/38969/hrI.js
# 35         https://s3.amazonaws.com/ki.js/38969/hrI.js
# 41          https://b-code.liadm.com/sync-container.js
# 43   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 44   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 47          https://b-code.liadm.com/sync-container.js
# ..                                                 ...
# 108  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 109  https://nexus.ensighten.com/mayo_clinic/clinic...
# 111  https://nexus.ensighten.com/mayo_clinic/clinic...
# 112      https://www.google-analytics.com/analytics.js
# 113            https://eus.rubiconproject.com/usync.js
# 116  https://www.medtargetsystem.com/js/build/porta...
# 118  https://nexus.ensighten.com/mayo_clinic/clinic...
# 119            https://eus.rubiconproject.com/usync.js
# 121  https://nexus.ensighten.com/mayo_clinic/clinic...
# 122  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 123  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 125      https://www.google-analytics.com/analytics.js
# 127  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 131  https://www.google-analytics.com/plugins/ua/li...
# 133  https://www.medtargetsystem.com/javascript/bea...
# 139            https://eus.rubiconproject.com/usync.js
# 140  https://www.medtargetsystem.com/javascript/bea...
# 142  https://www.gstatic.com/_/mss/boq-subscribewit...
# 143  https://contextual.media.net/bidexchange.js?ci...
# 146            https://eus.rubiconproject.com/usync.js
# 147            https://eus.rubiconproject.com/usync.js
# 148  https://www.googletagmanager.com/gtm.js?id=GTM...
# 150  https://gum.criteo.com/sync?r=2&c=321&j=window...
# 152  https://platform.iteratehq.com/sdk-prod-823cde...
# 153       https://static.chartbeat.com/js/chartbeat.js
# 157      https://www.google-analytics.com/analytics.js
# 163  https://gum.criteo.com/sync?r=2&c=321&j=window...
# 164      https://www.google-analytics.com/analytics.js
# 165       https://static.chartbeat.com/js/chartbeat.js
# 166  https://ads.pubmatic.com/AdServer/js/showad.js...
#
#                                   cookie_name  \
# 0                                      _liChk
# 1                                        s_sq
# 2                                        ki_t
# 5    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 6                                        mbox
# 7                             ctrHealthCenter
# 8    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 9                                  cto_bundle
# 10                                        aam
# 12                                 cto_bundle
# 13                                     prop29
# 14                                       mbox
# 15                         mnet_session_depth
# 16                         mnet_session_depth
# 19                                       _ibs
# 21                                      dextp
# 22                         mnet_session_depth
# 23                                        aam
# 24                                       ki_t
# 27                                     _liChk
# 28                              ctrPageviewId
# 29                                   _lc2_fpi
# 30                                        ctr
# 31                                     _liChk
# 32                                       ki_r
# 35                                       ki_t
# 41                                     _liChk
# 43   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 44                                       mbox
# 47                                     _liChk
# ..                                        ...
# 108                        QSI_HistorySession
# 109                                  kwCookie
# 111                                  kwCookie
# 112                                       _ga
# 113                                       pux
# 116                                 DMDSESSID
# 118                                  kwCookie
# 119                                       pux
# 121                                  kwCookie
# 122                        QSI_HistorySession
# 123                        QSI_HistorySession
# 125                                      _gid
# 127                        QSI_HistorySession
# 131                                     _gali
# 133                                   dmd-sid
# 139                                       pux
# 140                                     _sess
# 142                                       OTZ
# 143                        mnet_session_depth
# 146                                        cd
# 147                                       pux
# 148                                   _gcl_au
# 150                                cto_bundle
# 152                                   iter_id
# 153                               _chartbeat2
# 157                                    walley
# 163                            cto_write_test
# 164                                walley_gid
# 165                                       _cb
# 166                                        pi
#
#                                           cookie_value
# 0                                  0.14646394239970872
# 1                                        %5B%5BB%5D%5D
# 2    1606506096713%3B1606506096713%3B1606506128050%...
# 5    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 6    session#008c00a7adb142598621f56b2baa7b16#16065...
# 7                                        %5B%5BB%5D%5D
# 8    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 9    keV2al9sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WUpGQ3BTcH...
# 10                                        aam%3D999991
# 12   3dgWBF9sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WU1WbmQ4Y0...
# 13                                       %5B%5BB%5D%5D
# 14   session#008c00a7adb142598621f56b2baa7b16#16065...
# 15                                   5%7C1606506091348
# 16                                   2%7C1606506091348
# 19     0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997
# 21                              285689-1-1606506093357
# 22                                   1%7C1606506091348
# 23         aam%3D999991%2C529440%2C2819%2C2791%2C32920
# 24   1606506096713%3B1606506096713%3B1606506096713%...
# 27                                 0.17554361495773885
# 28                                       %5B%5BB%5D%5D
# 29            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 30                                       %5B%5BB%5D%5D
# 31                                  0.5881268258992058
# 32   aHR0cHM6Ly93d3cud2VibWQuY29tL3NlYXJjaC9zZWFyY2...
# 35   1606506096713%3B1606506096713%3B1606506158662%...
# 41                                  0.3761759546829273
# 43   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 44   session#008c00a7adb142598621f56b2baa7b16#16065...
# 47                                  0.4425675824200356
# ..                                                 ...
# 108  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 109           diabetes::diabetes::diabetes::diabetes::
# 111                               diabetes::diabetes::
# 112                          GA1.2.69243499.1606506249
# 113  1512%3D95611%262249%3D95611%262307%3D95611%262...
# 116               73dbf794-bf2b-443b-a147-2106183c5a0f
# 118                                         diabetes::
# 119  1185%3D95611%261512%3D95611%262082%3D95611%262...
# 121                     diabetes::diabetes::diabetes::
# 122  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 123  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 125                         GA1.2.765786451.1606506249
# 127  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 131                                             footer
# 133               7e986af6-3aa4-4bfc-a07b-ef7731ea581d
# 139  1185%3D95611%261512%3D95611%262132%3D95611%262...
# 140  7e986af6-3aa4-4bfc-a07b-ef7731ea581d.92f1226e-...
# 142                                 5736707_56_56__56_
# 143                                  1%7C1606506407646
# 146                                              false
# 147  1512%3D95611%262249%3D95611%262307%3D95611%262...
# 148                          1.1.1494308523.1606506416
# 150  CfULC19rVmJ6WmRRUU80RkFnZlBqVm9NeEFaaE8yTCUyRn...
# 152  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhaWQiO...
# 153  .1606506416769.1606506416769.1.B68Vf2Bu8WN0D4M...
# 157                        GA1.2.1349299055.1606506417
# 163                                          testWrite
# 164                        GA1.2.2028454572.1606506417
# 165                                   29rNyusPBLBDu1oZ
# 166                                           156011:2
#
# [99 rows x 5 columns]

# %%
conn_cookies = sqlite3.connect(exp_path)
javascript_cookies = pd.read_sql_query("select visit_id, record_type, change_cause, host, name, value, time_stamp from javascript_cookies;", conn_cookies)

# %%
javascript_cookies.host.unique()
# Out:
# array(['.www.webmd.com', '.js.webmd.com', '.img.webmd.com',
#        '.css.webmd.com', '.webmd.com', '.media.net', '.demdex.net',
#        '.scorecardresearch.com', 'www.webmd.com', '.turn.com',
#        '.rlcdn.com', 'ibclick.stream', '.liadm.com', 'i.liadm.com',
#        '.adsrvr.org', '.adnxs.com', '.bidswitch.net', '.doubleclick.net',
#        '.dotomi.com', '.dpm.demdex.net', '.mathtag.com', '.addthis.com',
#        '.amazon-adsystem.com', 'global.ib-ibi.com', '.pubmatic.com',
#        '.ads.pubmatic.com', '.adsymptotic.com', '.fiftyt.com',
#        '.everesttech.net', '.perf-serving.com', 'ib.mookie1.com',
#        '.ib.mookie1.com', '.dnacdn.net', '.1rx.io',
#        'eus.rubiconproject.com', '.casalemedia.com', '.yahoo.com',
#        '.advertising.com', '.3lift.com', '.yieldmo.com',
#        '.contextweb.com', 'bh.contextweb.com', '.rubiconproject.com',
#        '.analytics.yahoo.com', 'sync.srv.stackadapt.com',
#        '.srv.stackadapt.com', '.sitescout.com', '.adentifi.com',
#        '.advangelists.com', '.dyntrk.com', '.ads.yieldmo.com',
#        '.districtm.io', '.mookie1.com', '.targeting.unrulymedia.com',
#        '.emerse.com', '.bidr.io', '.exelator.com', '.quantserve.com',
#        '.tapad.com', '.rkdms.com', '.agkn.com', '.zemanta.com',
#        '.bluekai.com', '.crwdcntrl.net', '.rezync.com', 'live.rezync.com',
#        '.doctor.webmd.com', 'doctor.webmd.com', '.lkqd.net', '.simpli.fi',
#        '.mxptint.net', '.w55c.net', '.openx.net', '.rfihub.com',
#        'pool.admedo.com', '.smartadserver.com', '.technoratimedia.com',
#        '.iasds01.com', 'www.mayoclinic.org', '.www.mayoclinic.org',
#        '.youtube.com', '.bing.com', '.bat.bing.com', '.mayoclinic.org',
#        '.www.medtargetsystem.com', '.eloqua.com',
#        '.everydayhealth.demdex.net', '.nr-data.net', '.c.bing.com',
#        '.ads.linkedin.com', '.linkedin.com', '.ctnsnet.com',
#        'cs.chocolateplatform.com', '.uncn.jp', '.creative-serving.com',
#        '.mfadsrvr.com', 'bttrack.com', '.adform.net', '.smadex.com',
#        '.trendmd.com', 'www.swpsvc.com', '.caramel.press',
#        '.creativecdn.com', '.storygize.net', '.csync.loopme.me',
#        '.realestate.com.au', '.go.sonobi.com', '.ipredictive.com',
#        '.acuityplatform.com', '.us.ck-ie.com', 'id.knsso.com',
#        '.krxd.net', '.metadsp.co.uk', '.owneriq.net', '.id5-sync.com',
#        '.tidaltv.com', '.c.appier.net', '.adotmob.com', '.nytimes.com',
#        '.et.nytimes.com', 'www.nytimes.com', '.google.com',
#        'static01.nyt.com', '.a.nytimes.com', 'news.google.com',
#        '.twitter.com', '.insightexpressai.com',
#        '.verizonwireless.demdex.net'], dtype=object)

# %%
def clean_cookie_host(series):
    
    def helper(x):
        ls = x.strip('.').replace('.uk','').replace('.au','').split('.')
        return ls[-2]
    #     ind_com = ls.index('com')
    #     if ind_com > 0:
    #         return ls[ind_com - 1]
    #     elif ind_com == 0:
    #         return 'unknown'
    #     else:
    #         return 
    return list(map(lambda x: helper(x), series))

# %%
javascript_cookies['cleaned_host'] = clean_cookie_host(javascript_cookies.host)

# %%
javascript_cookies.host[javascript_cookies.host.str.contains("com.com")]
# Out:
# Series([], Name: host, dtype: object)

# %%
pd.merge(javascript_cookies, set_cookie_js, how ='inner',left_on=['name', 'value'], right_on=['cookie_name', 'cookie_value'])
# Out:
#      visit_id       record_type change_cause                    host  \
# 0           1  added-or-changed     explicit              .webmd.com
# 1           1  added-or-changed     explicit              .webmd.com
# 2           1  added-or-changed     explicit           www.webmd.com
# 3           1  added-or-changed     explicit              .webmd.com
# 4           1  added-or-changed     explicit              .webmd.com
# 5           1           deleted    overwrite              .webmd.com
# 6           1  added-or-changed     explicit              .webmd.com
# 7           1           deleted    overwrite              .webmd.com
# 8           1  added-or-changed     explicit              .webmd.com
# 9           1           deleted    overwrite              .webmd.com
# 10          1  added-or-changed     explicit              .webmd.com
# 11          1           deleted    overwrite              .webmd.com
# 12          1  added-or-changed     explicit              .webmd.com
# 13          1           deleted    overwrite              .webmd.com
# 14          1  added-or-changed     explicit              .webmd.com
# 15          1           deleted    overwrite              .webmd.com
# 16          1  added-or-changed     explicit              .webmd.com
# 17          1           deleted    overwrite              .webmd.com
# 18          1  added-or-changed     explicit              .webmd.com
# 19          1           deleted    overwrite              .webmd.com
# 20          1  added-or-changed     explicit              .webmd.com
# 21          1           deleted    overwrite              .webmd.com
# 22          1  added-or-changed     explicit              .webmd.com
# 23          1           deleted    overwrite              .webmd.com
# 24          1  added-or-changed     explicit              .webmd.com
# 25          1           deleted    overwrite              .webmd.com
# 26          1  added-or-changed     explicit              .webmd.com
# 27          1           deleted    overwrite              .webmd.com
# 28          1  added-or-changed     explicit              .webmd.com
# 29          1           deleted    overwrite              .webmd.com
# ..        ...               ...          ...                     ...
# 340         2           deleted    overwrite      www.mayoclinic.org
# 341         2  added-or-changed     explicit      www.mayoclinic.org
# 342         2           deleted    overwrite      www.mayoclinic.org
# 343         2  added-or-changed     explicit      www.mayoclinic.org
# 344         2           deleted    overwrite  eus.rubiconproject.com
# 345         2  added-or-changed     explicit  eus.rubiconproject.com
# 346         2           deleted    overwrite      www.mayoclinic.org
# 347         2  added-or-changed     explicit      www.mayoclinic.org
# 348         2           deleted    overwrite      www.mayoclinic.org
# 349         2  added-or-changed     explicit      www.mayoclinic.org
# 350         2           deleted    overwrite      www.mayoclinic.org
# 351         2  added-or-changed     explicit      www.mayoclinic.org
# 352         2           deleted    overwrite  eus.rubiconproject.com
# 353         2  added-or-changed     explicit  eus.rubiconproject.com
# 354         2           deleted    overwrite      www.mayoclinic.org
# 355         2  added-or-changed     explicit      www.mayoclinic.org
# 356         2           deleted    overwrite      www.mayoclinic.org
# 357         2  added-or-changed     explicit      www.mayoclinic.org
# 358         3  added-or-changed     explicit         www.nytimes.com
# 359         3  added-or-changed     explicit         news.google.com
# 360         3  added-or-changed     explicit            .nytimes.com
# 361         3  added-or-changed     explicit            .nytimes.com
# 362         3  added-or-changed     explicit            .nytimes.com
# 363         3  added-or-changed     explicit         www.nytimes.com
# 364         3  added-or-changed     explicit         www.nytimes.com
# 365         3  added-or-changed     explicit            .nytimes.com
# 366         3  added-or-changed     explicit            .nytimes.com
# 367         3  added-or-changed     explicit  eus.rubiconproject.com
# 368         3  added-or-changed     explicit           .pubmatic.com
# 369         3           deleted     explicit           .pubmatic.com
#
#                                          name  \
# 0    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 1                                        mbox
# 2                          mnet_session_depth
# 3                                  _li_dcdm_c
# 4                                    _lc2_fpi
# 5                                    _lc2_fpi
# 6                                    _lc2_fpi
# 7                                    _lc2_fpi
# 8                                    _lc2_fpi
# 9                                    _lc2_fpi
# 10                                   _lc2_fpi
# 11                                   _lc2_fpi
# 12                                   _lc2_fpi
# 13                                   _lc2_fpi
# 14                                   _lc2_fpi
# 15                                   _lc2_fpi
# 16                                   _lc2_fpi
# 17                                   _lc2_fpi
# 18                                   _lc2_fpi
# 19                                   _lc2_fpi
# 20                                   _lc2_fpi
# 21                                   _lc2_fpi
# 22                                   _lc2_fpi
# 23                                   _lc2_fpi
# 24                                   _lc2_fpi
# 25                                   _lc2_fpi
# 26                                   _lc2_fpi
# 27                                   _lc2_fpi
# 28                                   _lc2_fpi
# 29                                   _lc2_fpi
# ..                                        ...
# 340                                  kwCookie
# 341                                  kwCookie
# 342                        QSI_HistorySession
# 343                        QSI_HistorySession
# 344                                       pux
# 345                                       pux
# 346                        QSI_HistorySession
# 347                        QSI_HistorySession
# 348                                  kwCookie
# 349                                  kwCookie
# 350                        QSI_HistorySession
# 351                        QSI_HistorySession
# 352                                       pux
# 353                                       pux
# 354                                  kwCookie
# 355                                  kwCookie
# 356                        QSI_HistorySession
# 357                        QSI_HistorySession
# 358                        mnet_session_depth
# 359                                       OTZ
# 360                                   _gcl_au
# 361                                    walley
# 362                                walley_gid
# 363                                       _cb
# 364                               _chartbeat2
# 365                                cto_bundle
# 366                                   iter_id
# 367                                       pux
# 368                                        pi
# 369                                        pi
#
#                                                  value  \
# 0       -432600572%7CMCIDTS%7C18594%7CvVersion%7C4.5.2
# 1    session#008c00a7adb142598621f56b2baa7b16#16065...
# 2                                    1%7C1606506091348
# 3                                           .webmd.com
# 4             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 5             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 6             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 7             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 8             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 9             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 10            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 11            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 12            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 13            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 14            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 15            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 16            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 17            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 18            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 19            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 20            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 21            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 22            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 23            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 24            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 25            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 26            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 27            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 28            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 29            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# ..                                                 ...
# 340                               diabetes::diabetes::
# 341                               diabetes::diabetes::
# 342  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 343  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 344  1185%3D95611%261512%3D95611%262132%3D95611%262...
# 345  1185%3D95611%261512%3D95611%262132%3D95611%262...
# 346  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 347  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 348                     diabetes::diabetes::diabetes::
# 349                     diabetes::diabetes::diabetes::
# 350  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 351  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 352  1185%3D95611%261512%3D95611%262082%3D95611%262...
# 353  1185%3D95611%261512%3D95611%262082%3D95611%262...
# 354           diabetes::diabetes::diabetes::diabetes::
# 355           diabetes::diabetes::diabetes::diabetes::
# 356  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 357  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 358                                  1%7C1606506407646
# 359                                 5736707_56_56__56_
# 360                          1.1.1494308523.1606506416
# 361                        GA1.2.1349299055.1606506417
# 362                        GA1.2.2028454572.1606506417
# 363                                   29rNyusPBLBDu1oZ
# 364  .1606506416769.1606506416769.1.B68Vf2Bu8WN0D4M...
# 365  CfULC19rVmJ6WmRRUU80RkFnZlBqVm9NeEFaaE8yTCUyRn...
# 366  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhaWQiO...
# 367  1512%3D95611%262249%3D95611%262307%3D95611%262...
# 368                                           156011:2
# 369                                           156011:2
#
#                    time_stamp    cleaned_host origin_site       script_host  \
# 0    2020-11-27T19:41:30.376Z           webmd       webmd          adobedtm
# 1    2020-11-27T19:41:30.415Z           webmd       webmd          adobedtm
# 2    2020-11-27T19:41:31.351Z           webmd       webmd             media
# 3    2020-11-27T19:41:31.730Z           webmd       webmd             liadm
# 4    2020-11-27T19:41:31.732Z           webmd       webmd             liadm
# 5    2020-11-27T19:41:33.226Z           webmd       webmd             liadm
# 6    2020-11-27T19:41:33.229Z           webmd       webmd             liadm
# 7    2020-11-27T19:41:51.380Z           webmd       webmd             liadm
# 8    2020-11-27T19:41:51.380Z           webmd       webmd             liadm
# 9    2020-11-27T19:41:53.741Z           webmd       webmd             liadm
# 10   2020-11-27T19:41:53.742Z           webmd       webmd             liadm
# 11   2020-11-27T19:42:06.495Z           webmd       webmd             liadm
# 12   2020-11-27T19:42:06.495Z           webmd       webmd             liadm
# 13   2020-11-27T19:42:07.863Z           webmd       webmd             liadm
# 14   2020-11-27T19:42:07.863Z           webmd       webmd             liadm
# 15   2020-11-27T19:42:34.693Z           webmd       webmd             liadm
# 16   2020-11-27T19:42:34.694Z           webmd       webmd             liadm
# 17   2020-11-27T19:42:35.405Z           webmd       webmd             liadm
# 18   2020-11-27T19:42:35.406Z           webmd       webmd             liadm
# 19   2020-11-27T19:42:48.427Z           webmd       webmd             liadm
# 20   2020-11-27T19:42:48.427Z           webmd       webmd             liadm
# 21   2020-11-27T19:42:50.474Z           webmd       webmd             liadm
# 22   2020-11-27T19:42:50.474Z           webmd       webmd             liadm
# 23   2020-11-27T19:43:04.851Z           webmd       webmd             liadm
# 24   2020-11-27T19:43:04.851Z           webmd       webmd             liadm
# 25   2020-11-27T19:43:11.047Z           webmd       webmd             liadm
# 26   2020-11-27T19:43:11.048Z           webmd       webmd             liadm
# 27   2020-11-27T19:43:35.279Z           webmd       webmd             liadm
# 28   2020-11-27T19:43:35.279Z           webmd       webmd             liadm
# 29   2020-11-27T19:43:39.250Z           webmd       webmd             liadm
# ..                        ...             ...         ...               ...
# 340  2020-11-27T19:45:02.064Z      mayoclinic  mayoclinic         ensighten
# 341  2020-11-27T19:45:02.065Z      mayoclinic  mayoclinic         ensighten
# 342  2020-11-27T19:45:11.345Z      mayoclinic  mayoclinic     siteintercept
# 343  2020-11-27T19:45:11.345Z      mayoclinic  mayoclinic     siteintercept
# 344  2020-11-27T19:45:23.207Z  rubiconproject  mayoclinic    rubiconproject
# 345  2020-11-27T19:45:23.208Z  rubiconproject  mayoclinic    rubiconproject
# 346  2020-11-27T19:45:44.107Z      mayoclinic  mayoclinic     siteintercept
# 347  2020-11-27T19:45:44.107Z      mayoclinic  mayoclinic     siteintercept
# 348  2020-11-27T19:45:51.871Z      mayoclinic  mayoclinic         ensighten
# 349  2020-11-27T19:45:51.871Z      mayoclinic  mayoclinic         ensighten
# 350  2020-11-27T19:45:59.470Z      mayoclinic  mayoclinic     siteintercept
# 351  2020-11-27T19:45:59.471Z      mayoclinic  mayoclinic     siteintercept
# 352  2020-11-27T19:46:12.259Z  rubiconproject  mayoclinic    rubiconproject
# 353  2020-11-27T19:46:12.259Z  rubiconproject  mayoclinic    rubiconproject
# 354  2020-11-27T19:46:24.192Z      mayoclinic  mayoclinic         ensighten
# 355  2020-11-27T19:46:24.192Z      mayoclinic  mayoclinic         ensighten
# 356  2020-11-27T19:46:29.892Z      mayoclinic  mayoclinic     siteintercept
# 357  2020-11-27T19:46:29.893Z      mayoclinic  mayoclinic     siteintercept
# 358  2020-11-27T19:46:48.119Z         nytimes     nytimes             media
# 359  2020-11-27T19:46:55.754Z          google     nytimes           gstatic
# 360  2020-11-27T19:46:55.921Z         nytimes     nytimes  googletagmanager
# 361  2020-11-27T19:46:56.716Z         nytimes     nytimes  google-analytics
# 362  2020-11-27T19:46:56.742Z         nytimes     nytimes  google-analytics
# 363  2020-11-27T19:46:56.789Z         nytimes     nytimes         chartbeat
# 364  2020-11-27T19:46:56.791Z         nytimes     nytimes         chartbeat
# 365  2020-11-27T19:46:57.692Z         nytimes     nytimes            criteo
# 366  2020-11-27T19:46:57.743Z         nytimes     nytimes         iteratehq
# 367  2020-11-27T19:46:58.177Z  rubiconproject     nytimes    rubiconproject
# 368  2020-11-27T19:47:02.793Z        pubmatic     nytimes          pubmatic
# 369  2020-11-27T19:47:08.341Z        pubmatic     nytimes          pubmatic
#
#                                             script_url  \
# 0    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 1    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 2    https://contextual.media.net/bidexchange.js?ci...
# 3               https://b-code.liadm.com/a-00xm.min.js
# 4               https://b-code.liadm.com/a-00xm.min.js
# 5               https://b-code.liadm.com/a-00xm.min.js
# 6               https://b-code.liadm.com/a-00xm.min.js
# 7               https://b-code.liadm.com/a-00xm.min.js
# 8               https://b-code.liadm.com/a-00xm.min.js
# 9               https://b-code.liadm.com/a-00xm.min.js
# 10              https://b-code.liadm.com/a-00xm.min.js
# 11              https://b-code.liadm.com/a-00xm.min.js
# 12              https://b-code.liadm.com/a-00xm.min.js
# 13              https://b-code.liadm.com/a-00xm.min.js
# 14              https://b-code.liadm.com/a-00xm.min.js
# 15              https://b-code.liadm.com/a-00xm.min.js
# 16              https://b-code.liadm.com/a-00xm.min.js
# 17              https://b-code.liadm.com/a-00xm.min.js
# 18              https://b-code.liadm.com/a-00xm.min.js
# 19              https://b-code.liadm.com/a-00xm.min.js
# 20              https://b-code.liadm.com/a-00xm.min.js
# 21              https://b-code.liadm.com/a-00xm.min.js
# 22              https://b-code.liadm.com/a-00xm.min.js
# 23              https://b-code.liadm.com/a-00xm.min.js
# 24              https://b-code.liadm.com/a-00xm.min.js
# 25              https://b-code.liadm.com/a-00xm.min.js
# 26              https://b-code.liadm.com/a-00xm.min.js
# 27              https://b-code.liadm.com/a-00xm.min.js
# 28              https://b-code.liadm.com/a-00xm.min.js
# 29              https://b-code.liadm.com/a-00xm.min.js
# ..                                                 ...
# 340  https://nexus.ensighten.com/mayo_clinic/clinic...
# 341  https://nexus.ensighten.com/mayo_clinic/clinic...
# 342  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 343  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 344            https://eus.rubiconproject.com/usync.js
# 345            https://eus.rubiconproject.com/usync.js
# 346  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 347  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 348  https://nexus.ensighten.com/mayo_clinic/clinic...
# 349  https://nexus.ensighten.com/mayo_clinic/clinic...
# 350  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 351  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 352            https://eus.rubiconproject.com/usync.js
# 353            https://eus.rubiconproject.com/usync.js
# 354  https://nexus.ensighten.com/mayo_clinic/clinic...
# 355  https://nexus.ensighten.com/mayo_clinic/clinic...
# 356  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 357  https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 358  https://contextual.media.net/bidexchange.js?ci...
# 359  https://www.gstatic.com/_/mss/boq-subscribewit...
# 360  https://www.googletagmanager.com/gtm.js?id=GTM...
# 361      https://www.google-analytics.com/analytics.js
# 362      https://www.google-analytics.com/analytics.js
# 363       https://static.chartbeat.com/js/chartbeat.js
# 364       https://static.chartbeat.com/js/chartbeat.js
# 365  https://gum.criteo.com/sync?r=2&c=321&j=window...
# 366  https://platform.iteratehq.com/sdk-prod-823cde...
# 367            https://eus.rubiconproject.com/usync.js
# 368  https://ads.pubmatic.com/AdServer/js/showad.js...
# 369  https://ads.pubmatic.com/AdServer/js/showad.js...
#
#                                   cookie_name  \
# 0    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 1                                        mbox
# 2                          mnet_session_depth
# 3                                  _li_dcdm_c
# 4                                    _lc2_fpi
# 5                                    _lc2_fpi
# 6                                    _lc2_fpi
# 7                                    _lc2_fpi
# 8                                    _lc2_fpi
# 9                                    _lc2_fpi
# 10                                   _lc2_fpi
# 11                                   _lc2_fpi
# 12                                   _lc2_fpi
# 13                                   _lc2_fpi
# 14                                   _lc2_fpi
# 15                                   _lc2_fpi
# 16                                   _lc2_fpi
# 17                                   _lc2_fpi
# 18                                   _lc2_fpi
# 19                                   _lc2_fpi
# 20                                   _lc2_fpi
# 21                                   _lc2_fpi
# 22                                   _lc2_fpi
# 23                                   _lc2_fpi
# 24                                   _lc2_fpi
# 25                                   _lc2_fpi
# 26                                   _lc2_fpi
# 27                                   _lc2_fpi
# 28                                   _lc2_fpi
# 29                                   _lc2_fpi
# ..                                        ...
# 340                                  kwCookie
# 341                                  kwCookie
# 342                        QSI_HistorySession
# 343                        QSI_HistorySession
# 344                                       pux
# 345                                       pux
# 346                        QSI_HistorySession
# 347                        QSI_HistorySession
# 348                                  kwCookie
# 349                                  kwCookie
# 350                        QSI_HistorySession
# 351                        QSI_HistorySession
# 352                                       pux
# 353                                       pux
# 354                                  kwCookie
# 355                                  kwCookie
# 356                        QSI_HistorySession
# 357                        QSI_HistorySession
# 358                        mnet_session_depth
# 359                                       OTZ
# 360                                   _gcl_au
# 361                                    walley
# 362                                walley_gid
# 363                                       _cb
# 364                               _chartbeat2
# 365                                cto_bundle
# 366                                   iter_id
# 367                                       pux
# 368                                        pi
# 369                                        pi
#
#                                           cookie_value
# 0       -432600572%7CMCIDTS%7C18594%7CvVersion%7C4.5.2
# 1    session#008c00a7adb142598621f56b2baa7b16#16065...
# 2                                    1%7C1606506091348
# 3                                           .webmd.com
# 4             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 5             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 6             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 7             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 8             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 9             87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 10            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 11            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 12            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 13            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 14            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 15            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 16            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 17            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 18            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 19            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 20            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 21            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 22            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 23            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 24            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 25            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 26            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 27            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 28            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 29            87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# ..                                                 ...
# 340                               diabetes::diabetes::
# 341                               diabetes::diabetes::
# 342  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 343  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 344  1185%3D95611%261512%3D95611%262132%3D95611%262...
# 345  1185%3D95611%261512%3D95611%262132%3D95611%262...
# 346  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 347  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 348                     diabetes::diabetes::diabetes::
# 349                     diabetes::diabetes::diabetes::
# 350  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 351  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 352  1185%3D95611%261512%3D95611%262082%3D95611%262...
# 353  1185%3D95611%261512%3D95611%262082%3D95611%262...
# 354           diabetes::diabetes::diabetes::diabetes::
# 355           diabetes::diabetes::diabetes::diabetes::
# 356  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 357  https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 358                                  1%7C1606506407646
# 359                                 5736707_56_56__56_
# 360                          1.1.1494308523.1606506416
# 361                        GA1.2.1349299055.1606506417
# 362                        GA1.2.2028454572.1606506417
# 363                                   29rNyusPBLBDu1oZ
# 364  .1606506416769.1606506416769.1.B68Vf2Bu8WN0D4M...
# 365  CfULC19rVmJ6WmRRUU80RkFnZlBqVm9NeEFaaE8yTCUyRn...
# 366  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhaWQiO...
# 367  1512%3D95611%262249%3D95611%262307%3D95611%262...
# 368                                           156011:2
# 369                                           156011:2
#
# [370 rows x 13 columns]

# %%
set_cookies_merged = pd.merge(javascript_cookies, set_cookie_js, how ='inner',left_on=['name', 'value'], right_on=['cookie_name', 'cookie_value'])

# %%
js_cookies_distinct = javascript_cookies[['visit_id','host', 'name', 'value', 'cleaned_host']].drop_duplicates()

# %%
set_cookies_merged = pd.merge(js_cookies_distinct, set_cookie_js, how ='right',left_on=['name', 'value'], right_on=['cookie_name', 'cookie_value'])

# %%
get_cookies_merged = pd.merge(js_cookies_distinct, get_cookie_js, how ='right',left_on=['name', 'value'], right_on=['cookie_name', 'cookie_value'])

# %%
set_cookies_merged.shape
# Out:
# (108, 10)

# %%
get_cookies_merged.shape
# Out:
# (1748, 10)

# %%
pd.concat([set_cookies_merged, get_cookies_merged])
# Out:
#       visit_id                    host  \
# 0          1.0              .webmd.com
# 1          1.0              .webmd.com
# 2          1.0           www.webmd.com
# 3          1.0              .webmd.com
# 4          1.0              .webmd.com
# 5          1.0              .webmd.com
# 6          3.0            .nytimes.com
# 7          1.0              .webmd.com
# 8          3.0            .nytimes.com
# 9          1.0          ibclick.stream
# 10         1.0           www.webmd.com
# 11         1.0        doctor.webmd.com
# 12         1.0          ibclick.stream
# 13         1.0           www.webmd.com
# 14         1.0        doctor.webmd.com
# 15         1.0              .webmd.com
# 16         1.0              .webmd.com
# 17         1.0              .webmd.com
# 18         1.0              .webmd.com
# 19         1.0           www.webmd.com
# 20         1.0              .webmd.com
# 21         1.0              .webmd.com
# 22         1.0              .webmd.com
# 23         1.0             .demdex.net
# 24         1.0              .webmd.com
# 25         1.0              .webmd.com
# 26         1.0       .doctor.webmd.com
# 27         1.0           .pubmatic.com
# 28         1.0              .webmd.com
# 29         1.0           www.webmd.com
# ...        ...                     ...
# 1718       3.0            .nytimes.com
# 1719       3.0            .nytimes.com
# 1720       3.0     .rubiconproject.com
# 1721       3.0     .rubiconproject.com
# 1722       3.0              .media.net
# 1723       3.0  eus.rubiconproject.com
# 1724       3.0              .media.net
# 1725       3.0     .rubiconproject.com
# 1726       3.0           .pubmatic.com
# 1727       3.0           .pubmatic.com
# 1728       3.0           .pubmatic.com
# 1729       3.0           .pubmatic.com
# 1730       3.0           .pubmatic.com
# 1731       3.0           .pubmatic.com
# 1732       3.0           .pubmatic.com
# 1733       3.0           .pubmatic.com
# 1734       3.0           .pubmatic.com
# 1735       3.0           .pubmatic.com
# 1736       NaN                     NaN
# 1737       NaN                     NaN
# 1738       NaN                     NaN
# 1739       NaN                     NaN
# 1740       NaN                     NaN
# 1741       NaN                     NaN
# 1742       NaN                     NaN
# 1743       NaN                     NaN
# 1744       NaN                     NaN
# 1745       NaN                     NaN
# 1746       NaN                     NaN
# 1747       NaN                     NaN
#
#                                           name  \
# 0     AMCV_16AD4362526701720A490D45%40AdobeOrg
# 1                                         mbox
# 2                           mnet_session_depth
# 3                                   _li_dcdm_c
# 4                                     _lc2_fpi
# 5                               cto_write_test
# 6                               cto_write_test
# 7                               cto_write_test
# 8                               cto_write_test
# 9                                         _ibp
# 10                                        _ibp
# 11                                        _ibp
# 12                                        _ibs
# 13                                        _ibs
# 14                                        _ibs
# 15    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 16    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 17    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 18    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 19                                      _liChk
# 20    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 21    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 22                                        mbox
# 23                                       dextp
# 24                                         aam
# 25                                    aam_uuid
# 26                                    aam_uuid
# 27                                          pi
# 28                                  cto_bundle
# 29                                        ki_t
# ...                                        ...
# 1718                                   iter_id
# 1719                                   iter_id
# 1720                                     khaos
# 1721                                     audit
# 1722                                   data-bs
# 1723                                       pux
# 1724                                    data-r
# 1725                                     audit
# 1726                                        pi
# 1727                             KADUSERCOOKIE
# 1728                                  SyncRTB2
# 1729                             KRTBCOOKIE_80
# 1730                            KRTBCOOKIE_148
# 1731                                      PugT
# 1732                            KRTBCOOKIE_218
# 1733                             KRTBCOOKIE_22
# 1734                            KRTBCOOKIE_377
# 1735                            KRTBCOOKIE_330
# 1736                                       NaN
# 1737                                       NaN
# 1738                                       NaN
# 1739                                       NaN
# 1740                                       NaN
# 1741                                       NaN
# 1742                                       NaN
# 1743                                       NaN
# 1744                                       NaN
# 1745                                       NaN
# 1746                                       NaN
# 1747                                       NaN
#
#                                                   value    cleaned_host  \
# 0        -432600572%7CMCIDTS%7C18594%7CvVersion%7C4.5.2           webmd
# 1     session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 2                                     1%7C1606506091348           webmd
# 3                                            .webmd.com           webmd
# 4              87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35           webmd
# 5                                             testWrite           webmd
# 6                                             testWrite         nytimes
# 7                                             testWrite           webmd
# 8                                             testWrite         nytimes
# 9       0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631         ibclick
# 10      0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631           webmd
# 11      0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631           webmd
# 12      0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997         ibclick
# 13      0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997           webmd
# 14      0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997           webmd
# 15    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 16    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 17    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 18    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 19                                   0.4425675824200356           webmd
# 20    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 21    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 22    session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 23                               285689-1-1606506093357          demdex
# 24                                         aam%3D999991           webmd
# 25               45429554768808693152241494766003155399           webmd
# 26               45429554768808693152241494766003155399           webmd
# 27                                             156176:2        pubmatic
# 28    keV2al9sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WUpGQ3BTcH...           webmd
# 29    1606506096713%3B1606506096713%3B1606506096713%...           webmd
# ...                                                 ...             ...
# 1718  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhaWQiO...         nytimes
# 1719  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhaWQiO...         nytimes
# 1720                                   KI0OFXCE-1Y-LLAW  rubiconproject
# 1721  1|vaQE95Gfff45c/RJyrYP2sbnmVMdZQtRNpYwjXUD5iNI...  rubiconproject
# 1722            ac654ccd-05e0-467c-845c-c253a8b6cf35~~1           media
# 1723  1512%3D95611%262249%3D95611%262307%3D95611%262...  rubiconproject
# 1724                                KI0OFXCE-1Y-LLAW~~1           media
# 1725  1|vaQE95Gfff45c/RJyrYP2sbnmVMdZQtRNpYwjXUD5iNI...  rubiconproject
# 1726                                           156011:2        pubmatic
# 1727               7F2423D3-6D9C-4955-A0D1-FDCD4ED4152D        pubmatic
# 1728      1607644800%3A22_220_21_13_54%7C1607040000%3A2        pubmatic
# 1729  16514-CAESEEg-gMFYnmrpbfHi-amE230&KRTB&22987-C...        pubmatic
# 1730         19421-uid:4EAFDB5598B24221A4064F0DA90BAA82        pubmatic
# 1731                                         1606506425        pubmatic
# 1732  22978-X8FXsQAAAK3UbCzr&KRTB&23194-X8FXsQAAAK3U...        pubmatic
# 1733                          14911-8420827058598343980        pubmatic
# 1734  22918-d24f4722-bea6-4b76-9e07-7a4cf47fb964&KRT...        pubmatic
# 1735  22938-8404820d8b2b85b7e285c2b1d4449fa0&KRTB&22...        pubmatic
# 1736                                                NaN             NaN
# 1737                                                NaN             NaN
# 1738                                                NaN             NaN
# 1739                                                NaN             NaN
# 1740                                                NaN             NaN
# 1741                                                NaN             NaN
# 1742                                                NaN             NaN
# 1743                                                NaN             NaN
# 1744                                                NaN             NaN
# 1745                                                NaN             NaN
# 1746                                                NaN             NaN
# 1747                                                NaN             NaN
#
#      origin_site       script_host  \
# 0          webmd          adobedtm
# 1          webmd          adobedtm
# 2          webmd             media
# 3          webmd             liadm
# 4          webmd             liadm
# 5          webmd            criteo
# 6          webmd            criteo
# 7        nytimes            criteo
# 8        nytimes            criteo
# 9          webmd            stream
# 10         webmd            stream
# 11         webmd            stream
# 12         webmd            stream
# 13         webmd            stream
# 14         webmd            stream
# 15         webmd          adobedtm
# 16         webmd          adobedtm
# 17         webmd          adobedtm
# 18         webmd          adobedtm
# 19         webmd             liadm
# 20         webmd          adobedtm
# 21         webmd          adobedtm
# 22         webmd          adobedtm
# 23         webmd            demdex
# 24         webmd          adobedtm
# 25         webmd          adobedtm
# 26         webmd          adobedtm
# 27         webmd          pubmatic
# 28         webmd            criteo
# 29         webmd         amazonaws
# ...          ...               ...
# 1718     nytimes  googletagmanager
# 1719     nytimes                 g
# 1720     nytimes    rubiconproject
# 1721     nytimes    rubiconproject
# 1722     nytimes             media
# 1723     nytimes    rubiconproject
# 1724     nytimes             media
# 1725     nytimes    rubiconproject
# 1726     nytimes          pubmatic
# 1727     nytimes          pubmatic
# 1728     nytimes          pubmatic
# 1729     nytimes          pubmatic
# 1730     nytimes          pubmatic
# 1731     nytimes          pubmatic
# 1732     nytimes          pubmatic
# 1733     nytimes          pubmatic
# 1734     nytimes          pubmatic
# 1735     nytimes          pubmatic
# 1736  mayoclinic    rubiconproject
# 1737  mayoclinic    rubiconproject
# 1738  mayoclinic    rubiconproject
# 1739  mayoclinic    rubiconproject
# 1740     nytimes  googletagmanager
# 1741     nytimes                 g
# 1742     nytimes  google-analytics
# 1743     nytimes  googletagmanager
# 1744     nytimes   amazon-adsystem
# 1745     nytimes         iteratehq
# 1746     nytimes         chartbeat
# 1747     nytimes            criteo
#
#                                              script_url  \
# 0     https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 1     https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 2     https://contextual.media.net/bidexchange.js?ci...
# 3                https://b-code.liadm.com/a-00xm.min.js
# 4                https://b-code.liadm.com/a-00xm.min.js
# 5     https://gum.criteo.com/sync?r=2&c=321&j=window...
# 6     https://gum.criteo.com/sync?r=2&c=321&j=window...
# 7     https://gum.criteo.com/sync?r=2&c=321&j=window...
# 8     https://gum.criteo.com/sync?r=2&c=321&j=window...
# 9     https://ibclick.stream/assets/js/track/dist/js...
# 10    https://ibclick.stream/assets/js/track/dist/js...
# 11    https://ibclick.stream/assets/js/track/dist/js...
# 12    https://ibclick.stream/assets/js/track/dist/js...
# 13    https://ibclick.stream/assets/js/track/dist/js...
# 14    https://ibclick.stream/assets/js/track/dist/js...
# 15    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 16    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 17    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 18    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 19           https://b-code.liadm.com/sync-container.js
# 20    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 21    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 22    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 23    https://webmd.demdex.net/dest5.html?d_nsid=0#h...
# 24    https://assets.adobedtm.com/extensions/EP5e9ec...
# 25    https://assets.adobedtm.com/extensions/EP5e9ec...
# 26    https://assets.adobedtm.com/extensions/EP5e9ec...
# 27    https://ads.pubmatic.com/AdServer/js/showad.js...
# 28    https://gum.criteo.com/sync?r=2&c=321&j=window...
# 29          https://s3.amazonaws.com/ki.js/38969/hrI.js
# ...                                                 ...
# 1718  https://www.googletagmanager.com/gtm.js?id=GTM...
# 1719  https://securepubads.g.doubleclick.net/gpt/pub...
# 1720            https://eus.rubiconproject.com/usync.js
# 1721            https://eus.rubiconproject.com/usync.js
# 1722  https://contextual.media.net/checksync.php?&vs...
# 1723            https://eus.rubiconproject.com/usync.js
# 1724  https://contextual.media.net/checksync.php?&vs...
# 1725            https://eus.rubiconproject.com/usync.js
# 1726  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1727  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1728  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1729  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1730  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1731  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1732  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1733  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1734  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1735  https://ads.pubmatic.com/AdServer/js/showad.js...
# 1736            https://eus.rubiconproject.com/usync.js
# 1737            https://eus.rubiconproject.com/usync.js
# 1738            https://eus.rubiconproject.com/usync.js
# 1739            https://eus.rubiconproject.com/usync.js
# 1740  https://www.googletagmanager.com/gtm.js?id=GTM...
# 1741  https://securepubads.g.doubleclick.net/gpt/pub...
# 1742      https://www.google-analytics.com/analytics.js
# 1743  https://www.googletagmanager.com/gtm.js?id=GTM...
# 1744       https://c.amazon-adsystem.com/aax2/apstag.js
# 1745  https://platform.iteratehq.com/sdk-prod-823cde...
# 1746       https://static.chartbeat.com/js/chartbeat.js
# 1747  https://gum.criteo.com/sync?r=2&c=321&j=window...
#
#                                    cookie_name  \
# 0     AMCV_16AD4362526701720A490D45%40AdobeOrg
# 1                                         mbox
# 2                           mnet_session_depth
# 3                                   _li_dcdm_c
# 4                                     _lc2_fpi
# 5                               cto_write_test
# 6                               cto_write_test
# 7                               cto_write_test
# 8                               cto_write_test
# 9                                         _ibp
# 10                                        _ibp
# 11                                        _ibp
# 12                                        _ibs
# 13                                        _ibs
# 14                                        _ibs
# 15    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 16    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 17    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 18    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 19                                      _liChk
# 20    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 21    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 22                                        mbox
# 23                                       dextp
# 24                                         aam
# 25                                    aam_uuid
# 26                                    aam_uuid
# 27                                          pi
# 28                                  cto_bundle
# 29                                        ki_t
# ...                                        ...
# 1718                                   iter_id
# 1719                                   iter_id
# 1720                                     khaos
# 1721                                     audit
# 1722                                   data-bs
# 1723                                       pux
# 1724                                    data-r
# 1725                                     audit
# 1726                                        pi
# 1727                             KADUSERCOOKIE
# 1728                                  SyncRTB2
# 1729                             KRTBCOOKIE_80
# 1730                            KRTBCOOKIE_148
# 1731                                      PugT
# 1732                            KRTBCOOKIE_218
# 1733                             KRTBCOOKIE_22
# 1734                            KRTBCOOKIE_377
# 1735                            KRTBCOOKIE_330
# 1736                                     audit
# 1737                                     audit
# 1738                                     audit
# 1739                                      rsid
# 1740                                     nyt-m
# 1741                                     nyt-m
# 1742                                     nyt-m
# 1743                                     nyt-m
# 1744                                     nyt-m
# 1745                                     nyt-m
# 1746                                     nyt-m
# 1747                                     nyt-m
#
#                                            cookie_value
# 0        -432600572%7CMCIDTS%7C18594%7CvVersion%7C4.5.2
# 1     session#008c00a7adb142598621f56b2baa7b16#16065...
# 2                                     1%7C1606506091348
# 3                                            .webmd.com
# 4              87ca8f4d258a--01er5kk55nbdhke6vdd9ys5s35
# 5                                             testWrite
# 6                                             testWrite
# 7                                             testWrite
# 8                                             testWrite
# 9       0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631
# 10      0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631
# 11      0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631
# 12      0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997
# 13      0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997
# 14      0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997
# 15    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 16    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 17    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 18    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 19                                   0.4425675824200356
# 20    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 21    -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 22    session#008c00a7adb142598621f56b2baa7b16#16065...
# 23                               285689-1-1606506093357
# 24                                         aam%3D999991
# 25               45429554768808693152241494766003155399
# 26               45429554768808693152241494766003155399
# 27                                             156176:2
# 28    keV2al9sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WUpGQ3BTcH...
# 29    1606506096713%3B1606506096713%3B1606506096713%...
# ...                                                 ...
# 1718  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhaWQiO...
# 1719  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhaWQiO...
# 1720                                   KI0OFXCE-1Y-LLAW
# 1721  1|vaQE95Gfff45c/RJyrYP2sbnmVMdZQtRNpYwjXUD5iNI...
# 1722            ac654ccd-05e0-467c-845c-c253a8b6cf35~~1
# 1723  1512%3D95611%262249%3D95611%262307%3D95611%262...
# 1724                                KI0OFXCE-1Y-LLAW~~1
# 1725  1|vaQE95Gfff45c/RJyrYP2sbnmVMdZQtRNpYwjXUD5iNI...
# 1726                                           156011:2
# 1727               7F2423D3-6D9C-4955-A0D1-FDCD4ED4152D
# 1728      1607644800%3A22_220_21_13_54%7C1607040000%3A2
# 1729  16514-CAESEEg-gMFYnmrpbfHi-amE230&KRTB&22987-C...
# 1730         19421-uid:4EAFDB5598B24221A4064F0DA90BAA82
# 1731                                         1606506425
# 1732  22978-X8FXsQAAAK3UbCzr&KRTB&23194-X8FXsQAAAK3U...
# 1733                          14911-8420827058598343980
# 1734  22918-d24f4722-bea6-4b76-9e07-7a4cf47fb964&KRT...
# 1735  22938-8404820d8b2b85b7e285c2b1d4449fa0&KRTB&22...
# 1736  1|clb2f5t+FPpRSZbMWCS6IkhwzfSmyUn0h3b8gzcACzRu...
# 1737  1|clb2f5t+FPpRSZbMWCS6IkhwzfSmyUn0h3b8gzcACzRj...
# 1738  1|clb2f5t+FPpRSZbMWCS6IkhwzfSmyUn0h3b8gzcACzQT...
# 1739  1|DNi5OVoMr/vVSy6g0MQzNRXnpsxWJKbdvHdREsWffk0b...
# 1740                E3C27631C6F3938344AF74D86C2C60DC&vp
# 1741                E3C27631C6F3938344AF74D86C2C60DC&vp
# 1742                E3C27631C6F3938344AF74D86C2C60DC&vp
# 1743                E3C27631C6F3938344AF74D86C2C60DC&vp
# 1744                E3C27631C6F3938344AF74D86C2C60DC&vp
# 1745                E3C27631C6F3938344AF74D86C2C60DC&vp
# 1746                E3C27631C6F3938344AF74D86C2C60DC&vp
# 1747                E3C27631C6F3938344AF74D86C2C60DC&vp
#
# [1856 rows x 10 columns]

# %%
set_cookies_merged.sort_values(by=['value'])
# Out:
#      visit_id                    host  \
# 35        1.0              .webmd.com
# 20        1.0              .webmd.com
# 18        1.0              .webmd.com
# 21        1.0              .webmd.com
# 17        1.0              .webmd.com
# 16        1.0              .webmd.com
# 15        1.0              .webmd.com
# 0         1.0              .webmd.com
# 94        3.0         www.nytimes.com
# 3         1.0              .webmd.com
# 59        1.0           www.webmd.com
# 65        1.0           www.webmd.com
# 62        1.0           www.webmd.com
# 19        1.0           www.webmd.com
# 38        1.0           www.webmd.com
# 43        1.0           www.webmd.com
# 55        1.0           www.webmd.com
# 11        1.0        doctor.webmd.com
# 10        1.0           www.webmd.com
# 9         1.0          ibclick.stream
# 14        1.0        doctor.webmd.com
# 12        1.0          ibclick.stream
# 13        1.0           www.webmd.com
# 2         1.0           www.webmd.com
# 46        1.0        doctor.webmd.com
# 88        3.0         www.nytimes.com
# 90        3.0            .nytimes.com
# 85        2.0  eus.rubiconproject.com
# 81        2.0  eus.rubiconproject.com
# 76        2.0  eus.rubiconproject.com
# ..        ...                     ...
# 77        2.0         .mayoclinic.org
# 40        1.0              .webmd.com
# 74        2.0      www.mayoclinic.org
# 78        2.0      www.mayoclinic.org
# 80        2.0      www.mayoclinic.org
# 82        2.0      www.mayoclinic.org
# 84        2.0      www.mayoclinic.org
# 87        2.0      www.mayoclinic.org
# 28        1.0              .webmd.com
# 1         1.0              .webmd.com
# 22        1.0              .webmd.com
# 37        1.0              .webmd.com
# 42        1.0              .webmd.com
# 47        1.0              .webmd.com
# 54        1.0              .webmd.com
# 58        1.0              .webmd.com
# 64        1.0              .webmd.com
# 6         3.0            .nytimes.com
# 7         1.0              .webmd.com
# 8         3.0            .nytimes.com
# 5         1.0              .webmd.com
# 99        NaN                     NaN
# 100       NaN                     NaN
# 101       NaN                     NaN
# 102       NaN                     NaN
# 103       NaN                     NaN
# 104       NaN                     NaN
# 105       NaN                     NaN
# 106       NaN                     NaN
# 107       NaN                     NaN
#
#                                          name  \
# 35                                       s_sq
# 20   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 18   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 21   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 17   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 16   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 15   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 0    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 94                                _chartbeat2
# 3                                  _li_dcdm_c
# 59                                     _liChk
# 65                                     _liChk
# 62                                     _liChk
# 19                                     _liChk
# 38                                     _liChk
# 43                                     _liChk
# 55                                     _liChk
# 11                                       _ibp
# 10                                       _ibp
# 9                                        _ibp
# 14                                       _ibs
# 12                                       _ibs
# 13                                       _ibs
# 2                          mnet_session_depth
# 46                         mnet_session_depth
# 88                         mnet_session_depth
# 90                                    _gcl_au
# 85                                        pux
# 81                                        pux
# 76                                        pux
# ..                                        ...
# 77                                      _gali
# 40                                 cto_bundle
# 74                         QSI_HistorySession
# 78                         QSI_HistorySession
# 80                         QSI_HistorySession
# 82                         QSI_HistorySession
# 84                         QSI_HistorySession
# 87                         QSI_HistorySession
# 28                                 cto_bundle
# 1                                        mbox
# 22                                       mbox
# 37                                       mbox
# 42                                       mbox
# 47                                       mbox
# 54                                       mbox
# 58                                       mbox
# 64                                       mbox
# 6                              cto_write_test
# 7                              cto_write_test
# 8                              cto_write_test
# 5                              cto_write_test
# 99                                        NaN
# 100                                       NaN
# 101                                       NaN
# 102                                       NaN
# 103                                       NaN
# 104                                       NaN
# 105                                       NaN
# 106                                       NaN
# 107                                       NaN
#
#                                                  value    cleaned_host  \
# 35                                       %5B%5BB%5D%5D           webmd
# 20   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 18   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 21   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 17   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 16   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 15   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...           webmd
# 0       -432600572%7CMCIDTS%7C18594%7CvVersion%7C4.5.2           webmd
# 94   .1606506416769.1606506416769.1.B68Vf2Bu8WN0D4M...         nytimes
# 3                                           .webmd.com           webmd
# 59                                 0.14646394239970872           webmd
# 65                                 0.17554361495773885           webmd
# 62                                  0.3761759546829273           webmd
# 19                                  0.4425675824200356           webmd
# 38                                  0.5400472890426031           webmd
# 43                                  0.5881268258992058           webmd
# 55                                  0.8563389961824588           webmd
# 11     0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631           webmd
# 10     0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631           webmd
# 9      0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631         ibclick
# 14     0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997           webmd
# 12     0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997         ibclick
# 13     0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997           webmd
# 2                                    1%7C1606506091348           webmd
# 46                                   1%7C1606506139718           webmd
# 88                                   1%7C1606506407646         nytimes
# 90                           1.1.1494308523.1606506416         nytimes
# 85   1185%3D95611%261512%3D95611%262082%3D95611%262...  rubiconproject
# 81   1185%3D95611%261512%3D95611%262132%3D95611%262...  rubiconproject
# 76   1512%3D95611%262249%3D95611%262307%3D95611%262...  rubiconproject
# ..                                                 ...             ...
# 77                                              footer      mayoclinic
# 40   hKsQa19sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WVBHNkhnUm...           webmd
# 74   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...      mayoclinic
# 78   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...      mayoclinic
# 80   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...      mayoclinic
# 82   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...      mayoclinic
# 84   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...      mayoclinic
# 87   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...      mayoclinic
# 28   keV2al9sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WUpGQ3BTcH...           webmd
# 1    session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 22   session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 37   session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 42   session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 47   session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 54   session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 58   session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 64   session#008c00a7adb142598621f56b2baa7b16#16065...           webmd
# 6                                            testWrite         nytimes
# 7                                            testWrite           webmd
# 8                                            testWrite         nytimes
# 5                                            testWrite           webmd
# 99                                                 NaN             NaN
# 100                                                NaN             NaN
# 101                                                NaN             NaN
# 102                                                NaN             NaN
# 103                                                NaN             NaN
# 104                                                NaN             NaN
# 105                                                NaN             NaN
# 106                                                NaN             NaN
# 107                                                NaN             NaN
#
#     origin_site       script_host  \
# 35        webmd          adobedtm
# 20        webmd          adobedtm
# 18        webmd          adobedtm
# 21        webmd          adobedtm
# 17        webmd          adobedtm
# 16        webmd          adobedtm
# 15        webmd          adobedtm
# 0         webmd          adobedtm
# 94      nytimes         chartbeat
# 3         webmd             liadm
# 59        webmd             liadm
# 65        webmd             liadm
# 62        webmd             liadm
# 19        webmd             liadm
# 38        webmd             liadm
# 43        webmd             liadm
# 55        webmd             liadm
# 11        webmd            stream
# 10        webmd            stream
# 9         webmd            stream
# 14        webmd            stream
# 12        webmd            stream
# 13        webmd            stream
# 2         webmd             media
# 46        webmd             media
# 88      nytimes             media
# 90      nytimes  googletagmanager
# 85   mayoclinic    rubiconproject
# 81   mayoclinic    rubiconproject
# 76   mayoclinic    rubiconproject
# ..          ...               ...
# 77   mayoclinic  google-analytics
# 40        webmd            criteo
# 74   mayoclinic     siteintercept
# 78   mayoclinic     siteintercept
# 80   mayoclinic     siteintercept
# 82   mayoclinic     siteintercept
# 84   mayoclinic     siteintercept
# 87   mayoclinic     siteintercept
# 28        webmd            criteo
# 1         webmd          adobedtm
# 22        webmd          adobedtm
# 37        webmd          adobedtm
# 42        webmd          adobedtm
# 47        webmd          adobedtm
# 54        webmd          adobedtm
# 58        webmd          adobedtm
# 64        webmd          adobedtm
# 6         webmd            criteo
# 7       nytimes            criteo
# 8       nytimes            criteo
# 5         webmd            criteo
# 99        webmd          adobedtm
# 100       webmd          adobedtm
# 101       webmd          adobedtm
# 102       webmd          adobedtm
# 103       webmd          adobedtm
# 104       webmd          adobedtm
# 105  mayoclinic   medtargetsystem
# 106  mayoclinic   medtargetsystem
# 107  mayoclinic   medtargetsystem
#
#                                             script_url  \
# 35   https://assets.adobedtm.com/extensions/EP5e9ec...
# 20   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 18   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 21   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 17   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 16   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 15   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 0    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 94        https://static.chartbeat.com/js/chartbeat.js
# 3               https://b-code.liadm.com/a-00xm.min.js
# 59          https://b-code.liadm.com/sync-container.js
# 65          https://b-code.liadm.com/sync-container.js
# 62          https://b-code.liadm.com/sync-container.js
# 19          https://b-code.liadm.com/sync-container.js
# 38          https://b-code.liadm.com/sync-container.js
# 43          https://b-code.liadm.com/sync-container.js
# 55          https://b-code.liadm.com/sync-container.js
# 11   https://ibclick.stream/assets/js/track/dist/js...
# 10   https://ibclick.stream/assets/js/track/dist/js...
# 9    https://ibclick.stream/assets/js/track/dist/js...
# 14   https://ibclick.stream/assets/js/track/dist/js...
# 12   https://ibclick.stream/assets/js/track/dist/js...
# 13   https://ibclick.stream/assets/js/track/dist/js...
# 2    https://contextual.media.net/bidexchange.js?ci...
# 46   https://contextual.media.net/bidexchange.js?ci...
# 88   https://contextual.media.net/bidexchange.js?ci...
# 90   https://www.googletagmanager.com/gtm.js?id=GTM...
# 85             https://eus.rubiconproject.com/usync.js
# 81             https://eus.rubiconproject.com/usync.js
# 76             https://eus.rubiconproject.com/usync.js
# ..                                                 ...
# 77   https://www.google-analytics.com/plugins/ua/li...
# 40   https://gum.criteo.com/sync?r=2&c=321&j=window...
# 74   https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 78   https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 80   https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 82   https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 84   https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 87   https://zn_a9290jo7eb4diuz-mayoclinicsurveys.s...
# 28   https://gum.criteo.com/sync?r=2&c=321&j=window...
# 1    https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 22   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 37   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 42   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 47   https://assets.adobedtm.com/2c8c1e17b98c/ab4d0...
# 54   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 58   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 64   https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 6    https://gum.criteo.com/sync?r=2&c=321&j=window...
# 7    https://gum.criteo.com/sync?r=2&c=321&j=window...
# 8    https://gum.criteo.com/sync?r=2&c=321&j=window...
# 5    https://gum.criteo.com/sync?r=2&c=321&j=window...
# 99   https://assets.adobedtm.com/extensions/EP5e9ec...
# 100  https://assets.adobedtm.com/extensions/EP5e9ec...
# 101  https://assets.adobedtm.com/extensions/EP5e9ec...
# 102  https://assets.adobedtm.com/extensions/EP5e9ec...
# 103  https://assets.adobedtm.com/extensions/EP5e9ec...
# 104  https://assets.adobedtm.com/extensions/EP5e9ec...
# 105  https://www.medtargetsystem.com/js/build/porta...
# 106  https://www.medtargetsystem.com/js/build/porta...
# 107  https://www.medtargetsystem.com/js/build/porta...
#
#                                   cookie_name  \
# 35                                       s_sq
# 20   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 18   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 21   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 17   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 16   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 15   AMCV_16AD4362526701720A490D45%40AdobeOrg
# 0    AMCV_16AD4362526701720A490D45%40AdobeOrg
# 94                                _chartbeat2
# 3                                  _li_dcdm_c
# 59                                     _liChk
# 65                                     _liChk
# 62                                     _liChk
# 19                                     _liChk
# 38                                     _liChk
# 43                                     _liChk
# 55                                     _liChk
# 11                                       _ibp
# 10                                       _ibp
# 9                                        _ibp
# 14                                       _ibs
# 12                                       _ibs
# 13                                       _ibs
# 2                          mnet_session_depth
# 46                         mnet_session_depth
# 88                         mnet_session_depth
# 90                                    _gcl_au
# 85                                        pux
# 81                                        pux
# 76                                        pux
# ..                                        ...
# 77                                      _gali
# 40                                 cto_bundle
# 74                         QSI_HistorySession
# 78                         QSI_HistorySession
# 80                         QSI_HistorySession
# 82                         QSI_HistorySession
# 84                         QSI_HistorySession
# 87                         QSI_HistorySession
# 28                                 cto_bundle
# 1                                        mbox
# 22                                       mbox
# 37                                       mbox
# 42                                       mbox
# 47                                       mbox
# 54                                       mbox
# 58                                       mbox
# 64                                       mbox
# 6                              cto_write_test
# 7                              cto_write_test
# 8                              cto_write_test
# 5                              cto_write_test
# 99                                 ctrTopicId
# 100                             ctrPageviewId
# 101                  ctrContentClassification
# 102                           ctrHealthCenter
# 103                                       ctr
# 104                                    prop29
# 105                                 DMDSESSID
# 106                                 DMDSESSID
# 107                                 DMDSESSID
#
#                                           cookie_value
# 35                                       %5B%5BB%5D%5D
# 20   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 18   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 21   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 17   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 16   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 15   -432600572%7CMCIDTS%7C18594%7CMCMID%7C45583913...
# 0       -432600572%7CMCIDTS%7C18594%7CvVersion%7C4.5.2
# 94   .1606506416769.1606506416769.1.B68Vf2Bu8WN0D4M...
# 3                                           .webmd.com
# 59                                 0.14646394239970872
# 65                                 0.17554361495773885
# 62                                  0.3761759546829273
# 19                                  0.4425675824200356
# 38                                  0.5400472890426031
# 43                                  0.5881268258992058
# 55                                  0.8563389961824588
# 11     0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631
# 10     0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631
# 9      0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8af67631
# 14     0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997
# 12     0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997
# 13     0:ki0o8yer:9e3b4936-0517-4944-9e1e-6310858e6997
# 2                                    1%7C1606506091348
# 46                                   1%7C1606506139718
# 88                                   1%7C1606506407646
# 90                           1.1.1494308523.1606506416
# 85   1185%3D95611%261512%3D95611%262082%3D95611%262...
# 81   1185%3D95611%261512%3D95611%262132%3D95611%262...
# 76   1512%3D95611%262249%3D95611%262307%3D95611%262...
# ..                                                 ...
# 77                                              footer
# 40   hKsQa19sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WVBHNkhnUm...
# 74   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 78   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 80   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 82   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 84   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 87   https%3A%2F%2Fwww.mayoclinic.org%2Fsearch%2Fse...
# 28   keV2al9sVXlBS3VvNTVtYmxkTXMlMkJpbXF0WUpGQ3BTcH...
# 1    session#008c00a7adb142598621f56b2baa7b16#16065...
# 22   session#008c00a7adb142598621f56b2baa7b16#16065...
# 37   session#008c00a7adb142598621f56b2baa7b16#16065...
# 42   session#008c00a7adb142598621f56b2baa7b16#16065...
# 47   session#008c00a7adb142598621f56b2baa7b16#16065...
# 54   session#008c00a7adb142598621f56b2baa7b16#16065...
# 58   session#008c00a7adb142598621f56b2baa7b16#16065...
# 64   session#008c00a7adb142598621f56b2baa7b16#16065...
# 6                                            testWrite
# 7                                            testWrite
# 8                                            testWrite
# 5                                            testWrite
# 99                                       %5B%5BB%5D%5D
# 100                                      %5B%5BB%5D%5D
# 101                                      %5B%5BB%5D%5D
# 102                                      %5B%5BB%5D%5D
# 103                                      %5B%5BB%5D%5D
# 104                                      %5B%5BB%5D%5D
# 105               73dbf794-bf2b-443b-a147-2106183c5a0f
# 106               73dbf794-bf2b-443b-a147-2106183c5a0f
# 107               73dbf794-bf2b-443b-a147-2106183c5a0f
#
# [108 rows x 10 columns]
