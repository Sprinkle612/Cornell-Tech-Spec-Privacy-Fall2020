# %%
import numpy as np
import pandas as pd

# %%
cookies = pd.read_csv('distinct_cookies_update.csv')

# %%
cookies.sort_values(by=['exp_type', 'exp_group', 'exp_index', 'value'], inplace=True)
cookies.shape
# Out:
# (27119, 9)

# %%
v = cookies.value.value_counts()

# %%
cookies_cleaned = cookies[cookies.value.isin(v.index[v.gt(1)])]

# %%
cookies_cleaned = cookies_cleaned[(cookies_cleaned.value.str.len() > 5) & (~cookies_cleaned.value.isin(['.forbes.com', '.webmd.com', 'cookie', 'testWrite','NO_DATA', '%24NOT_FOUND']))]

# %%
cookies_cleaned.shape
# Out:
# (5119, 9)

# %%
helper = cookies_cleaned.groupby(['exp_group', 'exp_type', 'exp_index', 'value']).size().reset_index(name='counts')
helper = helper[helper.counts > 1]
final_table = cookies_cleaned[cookies_cleaned.value.isin(helper.value.tolist())]

# %%
def extract_persistent_cookies(eg):
    tables = []
    for et in ['forbes', 'nyt', 'washington']:
        for i in range(1, 7):
            temp = final_table[(final_table.exp_group == eg) & (final_table.exp_index==i) & (final_table.exp_type == et)]
            helper = temp.groupby('value').size().reset_index(name='counts')
            helper = helper[helper.counts > 1]
            temp = temp[temp.value.isin(helper.value.tolist())]
            tables.append(temp)
    return pd.concat(tables)

# %%
t = extract_persistent_cookies('t')

# %%
c = extract_persistent_cookies('c')

# %%
c
# Out:
#          exp_type exp_group  exp_index  visit_id origin_site  \
# 8953       forbes         c          1         3      forbes
# 8971       forbes         c          1         3      forbes
# 8509       forbes         c          1         1       webmd
# 8526       forbes         c          1         1       webmd
# 9079       forbes         c          1         3      forbes
# ...           ...       ...        ...       ...         ...
# 21722  washington         c          6         1       webmd
# 21879  washington         c          6         1       webmd
# 21880  washington         c          6         1       webmd
# 21883  washington         c          6         1       webmd
# 21884  washington         c          6         1       webmd
#
#                    host        name  \
# 8953                1rx     _rxuuid
# 8971        unrulymedia     _rxuuid
# 8509                1rx     _rxuuid
# 8526        unrulymedia     _rxuuid
# 9079   insightexpressai         TID
# ...                 ...         ...
# 21722           yieldmo       ptrpp
# 21879             webmd      AWSALB
# 21880             webmd  AWSALBCORS
# 21883             webmd      AWSALB
# 21884             webmd  AWSALBCORS
#
#                                                    value  is_third_party
# 8953   %7B%22rx_uuid%22%3A%22RX-46ffe855-4bac-4aae-af...            True
# 8971   %7B%22rx_uuid%22%3A%22RX-46ffe855-4bac-4aae-af...            True
# 8509   %7B%22rx_uuid%22%3A%22RX-ca49ac1b-a560-4de3-b3...            True
# 8526   %7B%22rx_uuid%22%3A%22RX-ca49ac1b-a560-4de3-b3...            True
# 9079                00000000-0000-0002-0ac1-241606507600            True
# ...                                                  ...             ...
# 21722                                       nMROJQ6CRBJk            True
# 21879  oDrQx3E07TC2lKHpLzgVSaur4PTVf6u4+tE20aScErexTJ...           False
# 21880  oDrQx3E07TC2lKHpLzgVSaur4PTVf6u4+tE20aScErexTJ...           False
# 21883  y85k55vX4MYWhbdTcEh7wwWKgBogeXjKBw7b3Amwt0znyB...           False
# 21884  y85k55vX4MYWhbdTcEh7wwWKgBogeXjKBw7b3Amwt0znyB...           False
#
# [1492 rows x 9 columns]

# %%
same_site_diff_host = t.groupby(['origin_site','value'])['host'].unique().reset_index()
same_site_diff_host = same_site_diff_host[same_site_diff_host.host.str.len()>2]
same_site_diff_host
# same_site_diff_host.to_csv("persistent_same_site_diff_host.csv", index=False)
# Out:
#         origin_site                                 value  \
# 15           forbes                            1606507536
# 17           forbes                            1606507543
# 37           forbes                            1606944815
# 42           forbes                            1606946019
# 43           forbes                            1606946022
# 49           forbes                            1607812912
# 185      mayoclinic                            1606859854
# 199      mayoclinic                            1606944376
# 200      mayoclinic                            1606944377
# 201      mayoclinic                            1606944426
# 204      mayoclinic                            1606944689
# 205      mayoclinic                            1606944690
# 217      mayoclinic                            1606945918
# 468  washingtonpost                            1606506503
# 472  washingtonpost                            1606859115
# 480  washingtonpost                            1607812115
# 514           webmd  0013ff08-870a-4374-b22e-d1688d13a169
# 554           webmd  0dbb843f-7869-4d42-b93e-34dbeae8aee5
# 581           webmd                            1606685860
# 603           webmd                            1606929731
# 608           webmd                            1606939543
# 628           webmd                            1607811861
# 629           webmd                            1607811862
# 657           webmd                   2358906999681116989
# 663           webmd  30c56c9f-03f9-4731-ae3a-b9067d64d280
# 682           webmd  45dc03b2-1fc5-40c2-a8b9-68ef634d3296
# 695           webmd                   5880129886090318970
# 722           webmd                   8320426864595872773
# 807           webmd  bacee715-203d-4b7f-88be-f66b30dd3c3c
# 826           webmd  e3d00952-eed2-4e38-95cf-3db76455f603
# 836           webmd  f35a8d4c-7aca-42e3-aecb-4a4a30dc37a4
#
#                                                   host
# 15       [sportradarserving, yahoo, scorecardresearch]
# 17                      [pubmatic, pippio, myvisualiq]
# 37   [pubmatic, yahoo, creative-serving, scorecardr...
# 42     [pubmatic, insightexpressai, sportradarserving]
# 43               [scorecardresearch, pubmatic, pippio]
# 49               [pubmatic, admedo, scorecardresearch]
# 185                    [mfadsrvr, bidswitch, pubmatic]
# 199                    [bidswitch, mfadsrvr, pubmatic]
# 200                    [bidswitch, mfadsrvr, pubmatic]
# 201              [sportradarserving, pubmatic, pippio]
# 204                    [bidswitch, mfadsrvr, pubmatic]
# 205                    [bidswitch, mfadsrvr, pubmatic]
# 217               [pubmatic, pippio, creative-serving]
# 468                    [yahoo, bidswitch, creativecdn]
# 472                       [yahoo, bidswitch, pubmatic]
# 480                     [creativecdn, pubmatic, yahoo]
# 514                     [bidswitch, mfadsrvr, yieldmo]
# 554                     [bidswitch, yieldmo, mfadsrvr]
# 581                        [pubmatic, mfadsrvr, yahoo]
# 603                           [pswec, pubmatic, yahoo]
# 608             [creativecdn, yahoo, insightexpressai]
# 628                    [pubmatic, yahoo, perf-serving]
# 629              [pubmatic, perf-serving, creativecdn]
# 657                           [adnxs, yieldmo, emxdgt]
# 663                     [bidswitch, mfadsrvr, yieldmo]
# 682                     [bidswitch, mfadsrvr, yieldmo]
# 695                           [adnxs, yieldmo, emxdgt]
# 722                           [adnxs, yieldmo, emxdgt]
# 807                     [bidswitch, mfadsrvr, yieldmo]
# 826                     [bidswitch, yieldmo, mfadsrvr]
# 836                     [bidswitch, yieldmo, mfadsrvr]

# %%
# tmp = same_site_diff_host[['origin_site', 'host']]
# tmp['tmp'] = same_site_diff_host['host'].apply(lambda x: " ".join(x))
# tmp = tmp[['origin_site', 'tmp']].drop_duplicates().reset_index(drop=True)
# tmp

# %%
same_host_diff_site = c.groupby(['host','value'])['origin_site'].unique().reset_index()
same_host_diff_site = same_host_diff_site[same_host_diff_site.origin_site.str.len()>2]
same_host_diff_site.shape
# Out:
#                 host                                              value  \
# 18    acuityplatform                                        5.44733E+11
# 78            adsrvr               e8c800eb-9f3b-47a2-8ca7-c08d427ccf40
# 115  amazon-adsystem                            A5TceRFCZkaihlpGgUdYLUM
# 271      doubleclick                                 CheckForPermission
# 490         pubmatic                       1608076800%3A201_200_221_219
# 491         pubmatic               40B0D216-4F4E-4EA0-AC3A-CA32B02CA241
# 527            tapad                                        1.60686E+12
# 528            tapad                                        1.60694E+12
# 715            yahoo                             5djqgadfsfu09&b=3&s=48
# 716            yahoo                               AQEBAQFfyUlf0UIh_AS-
# 750            yahoo  d=AQABBAn4x18CEKQuNvzoLdWqvKOFYFNQz1YFEgEBAQFJ...
#
#                                            origin_site
# 18                     [webmd, forbes, washingtonpost]
# 78                        [webmd, mayoclinic, nytimes]
# 115                       [webmd, mayoclinic, nytimes]
# 271  [webmd, mayoclinic, forbes, nytimes, washingto...
# 490  [webmd, mayoclinic, forbes, nytimes, washingto...
# 491                       [webmd, mayoclinic, nytimes]
# 527                [webmd, mayoclinic, washingtonpost]
# 528                        [webmd, mayoclinic, forbes]
# 715                       [webmd, mayoclinic, nytimes]
# 716                       [webmd, mayoclinic, nytimes]
# 750                       [webmd, mayoclinic, nytimes]
