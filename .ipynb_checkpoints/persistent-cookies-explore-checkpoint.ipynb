# %%
import numpy as np
import pandas as pd

# %%
cookies = pd.read_csv('distinct_cookies_update.csv')

# %%
cookies.sort_values(by=['exp_type', 'exp_group', 'exp_index', 'value'], inplace=True)
cookies.shape
# Out:
# (27119, 9)

# %%
v = cookies.value.value_counts()

# %%
cookies_cleaned = cookies[cookies.value.isin(v.index[v.gt(1)])]

# %%
cookies_cleaned = cookies_cleaned[(cookies_cleaned.value.str.len() > 5) & (~cookies_cleaned.value.isin(['.forbes.com', '.webmd.com', 'cookie', 'testWrite','NO_DATA', '%24NOT_FOUND']))]

# %%
cookies_cleaned.shape
# Out:
# (5119, 9)

# %%
helper = cookies_cleaned.groupby(['exp_group', 'exp_type', 'exp_index', 'value']).size().reset_index(name='counts')
helper = helper[helper.counts > 1]
final_table = cookies_cleaned[cookies_cleaned.value.isin(helper.value.tolist())]

# %%
def extract_persistent_cookies(eg):
    tables = []
    for et in ['forbes', 'nyt', 'washington']:
        for i in range(1, 7):
            temp = final_table[(final_table.exp_group == eg) & (final_table.exp_index==i) & (final_table.exp_type == et)]
            helper = temp.groupby('value').size().reset_index(name='counts')
            helper = helper[helper.counts > 1]
            temp = temp[temp.value.isin(helper.value.tolist())]
            tables.append(temp)
    return pd.concat(tables)

# %%
extract_persistent_cookies('t')
# Out:
#          exp_type exp_group  exp_index  visit_id     origin_site  \
# 13491      forbes         t          1         2      mayoclinic
# 13494      forbes         t          1         2      mayoclinic
# 13609      forbes         t          1         3          forbes
# 13621      forbes         t          1         3          forbes
# 12987      forbes         t          1         1           webmd
# 13007      forbes         t          1         1           webmd
# 13428      forbes         t          1         2      mayoclinic
# 13431      forbes         t          1         2      mayoclinic
# 13248      forbes         t          1         1           webmd
# 13249      forbes         t          1         1           webmd
# 13815      forbes         t          1         3          forbes
# 13818      forbes         t          1         3          forbes
# 12912      forbes         t          1         1           webmd
# 12920      forbes         t          1         1           webmd
# 12913      forbes         t          1         1           webmd
# 12921      forbes         t          1         1           webmd
# 13233      forbes         t          1         1           webmd
# 13234      forbes         t          1         1           webmd
# 12940      forbes         t          1         1           webmd
# 12941      forbes         t          1         1           webmd
# 12980      forbes         t          1         1           webmd
# 12996      forbes         t          1         1           webmd
# 12997      forbes         t          1         1           webmd
# 13010      forbes         t          1         1           webmd
# 13032      forbes         t          1         1           webmd
# 13250      forbes         t          1         1           webmd
# 13253      forbes         t          1         1           webmd
# 13357      forbes         t          1         2      mayoclinic
# 13358      forbes         t          1         2      mayoclinic
# 13360      forbes         t          1         2      mayoclinic
# ...           ...       ...        ...       ...             ...
# 26904  washington         t          6         2      mayoclinic
# 26905  washington         t          6         2      mayoclinic
# 26710  washington         t          6         1           webmd
# 26965  washington         t          6         2      mayoclinic
# 26634  washington         t          6         1           webmd
# 26898  washington         t          6         2      mayoclinic
# 27060  washington         t          6         3  washingtonpost
# 27100  washington         t          6         3  washingtonpost
# 26628  washington         t          6         1           webmd
# 26684  washington         t          6         1           webmd
# 26623  washington         t          6         1           webmd
# 26851  washington         t          6         2      mayoclinic
# 26604  washington         t          6         1           webmd
# 26866  washington         t          6         2      mayoclinic
# 26690  washington         t          6         1           webmd
# 26691  washington         t          6         1           webmd
# 26817  washington         t          6         2      mayoclinic
# 26818  washington         t          6         2      mayoclinic
# 26716  washington         t          6         1           webmd
# 26717  washington         t          6         1           webmd
# 26973  washington         t          6         2      mayoclinic
# 26974  washington         t          6         2      mayoclinic
# 26776  washington         t          6         1           webmd
# 26778  washington         t          6         1           webmd
# 26658  washington         t          6         1           webmd
# 26864  washington         t          6         2      mayoclinic
# 26758  washington         t          6         1           webmd
# 26869  washington         t          6         2      mayoclinic
# 26631  washington         t          6         1           webmd
# 26692  washington         t          6         1           webmd
#
#                     host                 name  \
# 13491                1rx              _rxuuid
# 13494        unrulymedia              _rxuuid
# 13609                1rx              _rxuuid
# 13621        unrulymedia              _rxuuid
# 12987                1rx              _rxuuid
# 13007        unrulymedia              _rxuuid
# 13428   insightexpressai                  TID
# 13431   insightexpressai                   DW
# 13248   insightexpressai                  TID
# 13249   insightexpressai                   DW
# 13815   insightexpressai                  TID
# 13818   insightexpressai                   DW
# 12912            ibclick                 _ibp
# 12920              webmd                 _ibp
# 12913            ibclick                 _ibs
# 12921              webmd                 _ibs
# 13233     rubiconproject                ses15
# 13234     rubiconproject                vis15
# 12940          bidswitch                    c
# 12941          bidswitch             tuuid_lu
# 12980              yahoo               APIDTS
# 12996  sportradarserving                    c
# 12997  sportradarserving             zuuid_lu
# 13010  sportradarserving             zuuid_lu
# 13032              yahoo               APIDTS
# 13250   insightexpressai              DW_Time
# 13253               lkqd             lkqdidts
# 13357           mfadsrvr                    c
# 13358           mfadsrvr             tuuid_lu
# 13360          bidswitch                    c
# ...                  ...                  ...
# 26904             simpli                 suid
# 26905             simpli          suid_legacy
# 26710             rfihub                  rud
# 26965             rfihub                  rud
# 26634     rubiconproject                khaos
# 26898     rubiconproject                khaos
# 27060        advertising                 APID
# 27100              yahoo                 APID
# 26628        advertising                 APID
# 26684              yahoo                 APID
# 26623        casalemedia                 CMID
# 26851        casalemedia                 CMID
# 26604            mathtag                 uuid
# 26866            mathtag                 uuid
# 26690       tribalfusion              ANON_ID
# 26691       tribalfusion          ANON_ID_old
# 26817         mayoclinic          ARRAffinity
# 26818         mayoclinic  ARRAffinitySameSite
# 26716       tribalfusion              ANON_ID
# 26717       tribalfusion          ANON_ID_old
# 26973       tribalfusion              ANON_ID
# 26974       tribalfusion          ANON_ID_old
# 26776              webmd                as_02
# 26778              webmd             as_02_30
# 26658              yahoo                   A3
# 26864              yahoo                   A3
# 26758            zemanta                 zuid
# 26869            zemanta                 zuid
# 26631         contextweb                    V
# 26692            yieldmo                ptrpp
#
#                                                    value  is_third_party
# 13491  %7B%22rx_uuid%22%3A%22RX-8acd8bb4-f3e1-4ec8-b5...            True
# 13494  %7B%22rx_uuid%22%3A%22RX-8acd8bb4-f3e1-4ec8-b5...            True
# 13609  %7B%22rx_uuid%22%3A%22RX-d6f42649-119a-4828-85...            True
# 13621  %7B%22rx_uuid%22%3A%22RX-d6f42649-119a-4828-85...            True
# 12987  %7B%22rx_uuid%22%3A%22RX-f5e8b1de-4640-4485-a0...            True
# 13007  %7B%22rx_uuid%22%3A%22RX-f5e8b1de-4640-4485-a0...            True
# 13428               00000000-0000-0001-0f88-e51606507455            True
# 13431               00000000-0000-0001-0f88-e51606507455            True
# 13248               00000000-0000-0061-d845-231606507349            True
# 13249               00000000-0000-0061-d845-231606507349            True
# 13815               00000000-0000-008e-5f08-db1606507542            True
# 13818               00000000-0000-008e-5f08-db1606507542            True
# 12912    0:ki0owzd0:082c7cb4-925e-402b-a3cd-41164f9e04f4            True
# 12920    0:ki0owzd0:082c7cb4-925e-402b-a3cd-41164f9e04f4           False
# 12913    0:ki0owzd5:707a6baa-914e-4df9-bff4-4680e424df10            True
# 12921    0:ki0owzd5:707a6baa-914e-4df9-bff4-4680e424df10           False
# 13233                                           156916^1            True
# 13234                                           156916^1            True
# 12940                                         1606507214            True
# 12941                                         1606507214            True
# 12980                                         1606507214            True
# 12996                                         1606507215            True
# 12997                                         1606507215            True
# 13010                                         1606507216            True
# 13032                                         1606507216            True
# 13250                                         1606507349            True
# 13253                                         1606507349            True
# 13357                                         1606507395            True
# 13358                                         1606507395            True
# 13360                                         1606507395            True
# ...                                                  ...             ...
# 26904                   F72B2C226D2741FF80C01C5F8696BFB7            True
# 26905                   F72B2C226D2741FF80C01C5F8696BFB7            True
# 26710  H4sIAAAAAAAAAOMSNrQwNDYwNTCzNDUzMDY0NDc3NRHiM9...            True
# 26965  H4sIAAAAAAAAAOMSNrQwNDYwNTCzNDUzMDY0NDc3NRHiM9...            True
# 26634                                    KIM9O24B-F-3MPG            True
# 26898                                    KIM9O24B-F-3MPG            True
# 27060             UP5edfa422-3cc9-11eb-ae6c-0ad8849c0f17            True
# 27100             UP5edfa422-3cc9-11eb-ae6c-0ad8849c0f17            True
# 26628             UPc6987cd8-3cc8-11eb-8e74-0ebc72b95443            True
# 26684             UPc6987cd8-3cc8-11eb-8e74-0ebc72b95443            True
# 26623                           X9VDEgfMuXcqT6ihf8I3WgAA            True
# 26851                           X9VDEgfMuXcqT6ihf8I3WgAA            True
# 26604               a8d05fd5-4311-4900-ae5a-1471e1d833ab            True
# 26866               a8d05fd5-4311-4900-ae5a-1471e1d833ab            True
# 26690        aDnoeUrwZayqQXwrUPWvgdUhaUW0SuAZdr1Zbiv63r0            True
# 26691        aDnoeUrwZayqQXwrUPWvgdUhaUW0SuAZdr1Zbiv63r0            True
# 26817  acd238d147a0b70274b769a1815efd41db1a6c1460dbcd...           False
# 26818  acd238d147a0b70274b769a1815efd41db1a6c1460dbcd...           False
# 26716  avnrejtMPmEUTgUpMDV7obLIUVpIlnN9qsqVq7arcbZbnn...            True
# 26717  avnrejtMPmEUTgUpMDV7obLIUVpIlnN9qsqVq7arcbZbnn...            True
# 26973  awnt6ZayOZbSEoJTyBqZcuBN9HKjxmZdVISEUZaQqAZcaV...            True
# 26974  awnt6ZayOZbSEoJTyBqZcuBN9HKjxmZdVISEUZaQqAZcaV...            True
# 26776                                       ck_cntr1_740           False
# 26778                                       ck_cntr1_740           False
# 26658  d=AQABBBJD1V8CEFEXSdAjNB9sVP0VSTNWZR0FEgEBAQGU...            True
# 26864  d=AQABBBJD1V8CEFEXSdAjNB9sVP0VSTNWZR0FEgEBAQGU...            True
# 26758                               iuFTjCxdMkg8Y4-bpHQf            True
# 26869                               iuFTjCxdMkg8Y4-bpHQf            True
# 26631                                       vr9VfueIEimt            True
# 26692                                       vr9VfueIEimt            True
#
# [1944 rows x 9 columns]

# %%
c = extract_persistent_cookies('c')
