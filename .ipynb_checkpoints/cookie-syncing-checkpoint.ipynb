# %%
import numpy as np
import pandas as pd
import sqlite3
import sys
import os
import re
from urllib.parse import urlparse

# %%
# helper functions
def get_host_from_headers(x):
    temp = x.replace('"','').split('],[')
    for t in temp:
            pair = t.replace(']]','').replace('[[','').split(',')
            if "Host" in pair:
                host_value = pair[1]
    return host_value

def get_cookies_from_headers(x):
    ls = x.replace('"','').split('],[')
    for l in ls:
        ta = l.replace(']]','').split(',')
        if "Cookie" in ta:
            return ta[-1]
    return ''
def extract_host_from_url(url_ls):
    return list(map(lambda x: urlparse(x).netloc.split('.')[1] if len(urlparse(x).netloc.split('.')) > 1 else x, url_ls))

def get_site(site_url):
    return site_url.split(".")[1]

def is_third_party(origin, url_host):
    if origin in url_host:
        return False
    return True

def save_df_to_csv(df, file_name):
    df.to_csv(file_name+'.csv', index=False)

def extract_deep_clean_host(url):
    s = url.strip(".au").strip('.uk')
    return s.split('.')[-2] if len(s.split('.')) > 1 else s

# %%
query = """SELECT sv.site_url, sv.visit_id,
        hr.headers, hr.referrer, hr.url
        FROM http_requests as hr LEFT JOIN site_visits as sv
        ON sv.visit_id = hr.visit_id
        """
# query = """SELECT sv.site_url, sv.visit_id,
#         hr.headers, hr.referrer, hr.url, hr.top_level_url
#         FROM http_requests as hr LEFT JOIN site_visits as sv
#         ON sv.visit_id = hr.visit_id
#         """

# %%
conn = sqlite3.connect(sql_file)
http_requests = pd.read_sql_query(query, conn)

# %%
http_requests["host"] = list(map(lambda x: get_host_from_headers(x), http_requests.headers.tolist()))
http_requests["cookies"] =  list(map(lambda x: get_cookies_from_headers(x), http_requests.headers.tolist()))
http_requests["origin_site"] = list(map(lambda x: get_site(x), http_requests.site_url))
http_requests["is_third_party"] = list(map(lambda a, b: is_third_party(a, b), http_requests.origin_site, http_requests.host))
http_requests['referrer'] = list(map(lambda x: urlparse(x).netloc, http_requests.referrer))
http_requests['referred_by_third'] = list(map(lambda a, b: is_third_party(a, b), http_requests.origin_site, http_requests.referrer))

# %%
data = http_requests[http_requests.is_third_party == True][["origin_site", \
                                                            "host", "referrer", "referred_by_third", "url", "cookies"]].reset_index(drop = True)

# %%
data
# Out:
#      origin_site                          host         referrer  \
# 0          webmd           assets.adobedtm.com    www.webmd.com
# 1          webmd      www.googleadservices.com    www.webmd.com
# 2          webmd          fonts.googleapis.com    css.webmd.com
# 3          webmd          fonts.googleapis.com    css.webmd.com
# 4          webmd  dyv1bugovvq1g.cloudfront.net    www.webmd.com
# ...          ...                           ...              ...
# 2048     nytimes            cdn.ampproject.org  www.nytimes.com
# 2049     nytimes            cdn.ampproject.org  www.nytimes.com
# 2050     nytimes            cdn.ampproject.org  www.nytimes.com
# 2051     nytimes            cdn.ampproject.org  www.nytimes.com
# 2052     nytimes            cdn.ampproject.org  www.nytimes.com
#
#       referred_by_third                                                url  \
# 0                 False  https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 1                 False  https://www.googleadservices.com/pagead/conver...
# 2                 False  https://fonts.googleapis.com/css?family=Roboto...
# 3                 False  https://fonts.googleapis.com/css?family=Roboto...
# 4                 False  https://dyv1bugovvq1g.cloudfront.net/25/www.we...
# ...                 ...                                                ...
# 2048              False  https://cdn.ampproject.org/rtv/012010270040000...
# 2049              False  https://cdn.ampproject.org/rtv/012010270040000...
# 2050              False  https://cdn.ampproject.org/rtv/012010270040000...
# 2051              False  https://cdn.ampproject.org/rtv/012010270040000...
# 2052              False  https://cdn.ampproject.org/rtv/012010270040000...
#
#      cookies
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 2048
# 2049
# 2050
# 2051
# 2052
#
# [2053 rows x 6 columns]

# %%
# all entries are referred by third party
# data[data.referred_by_third]

# %%
query2 = """SELECT sv.site_url, sv.visit_id,
        jsc.host, jsc.name, jsc.value
        FROM javascript_cookies as jsc LEFT JOIN site_visits as sv
        ON sv.visit_id = jsc.visit_id
        """
cookies = pd.read_sql_query(query2, conn)

# %%
cookies['origin_site'] = list(map(lambda x: get_site(x), cookies.site_url))
cookies['is_third_party'] = list(map(lambda a, b: is_third_party(a, b), cookies.origin_site, cookies.host))

# %%
cookies_data = cookies[["origin_site", "host", "name", "value", "is_third_party"]]
cookies_data
# Out:
#      origin_site                  host         name  \
# 0          webmd        .www.webmd.com     __cfduid
# 1          webmd            .webmd.com      lrt_wrk
# 2          webmd            .webmd.com       gtinfo
# 3          webmd            .webmd.com    VisitorId
# 4          webmd        .css.webmd.com     __cfduid
# ...          ...                   ...          ...
# 1391     nytimes            .yahoo.com          GUC
# 1392     nytimes         .pubmatic.com  KTPCACOOKIE
# 1393     nytimes  .analytics.yahoo.com       IDSYNC
# 1394     nytimes     .ads.pubmatic.com         KCCH
# 1395     nytimes         .pubmatic.com           pi
#
#                                                   value  is_third_party
# 0           dd673b2700baa134208e3794c02eec1f41606506583           False
# 1     lrt1_cached_k8_worker_1_37S_21O_2020-11-18_17:...           False
# 2     {"ct":"Columbus","c":"Franklin","cc":"39049","...           False
# 3                  9831e05f-086b-4123-5987-f9b5df875967           False
# 4           dc560e081e9789ea111079dc63ad819771606506583           False
# ...                                                 ...             ...
# 1391                               AQEBAQFfwqtfy0IcvQQZ            True
# 1392                                                YES            True
# 1393                                          18y3~1v0j            True
# 1394                                                YES            True
# 1395                                           156011:2            True
#
# [1396 rows x 5 columns]

# %%
cookie_fp = [re.escape(v) for v in set(cookies_data[cookies_data.is_third_party == False].value) if len(v) > 5]
cookie_tp = [re.escape(v) for v in set(cookies_data[cookies_data.is_third_party == True].value) if len(v) > 5]

cookie_fp_string = "|".join(cookie_fp)
cookie_tp_string = "|".join(cookie_tp)

# %%
cookie_values = [re.escape(v) for v in set(cookies.value) if len(v) > 5]
cookie_values_string = "|".join(cookie_values)

# %%
# len(cookie_values_string)

# %%
# http_requests_syncs = http_requests_third_party[http_requests_third_party.url.str.contains(fp_cookie_values, regex=True)]
# http_requests_syncs = http_requests_third_party[http_requests_third_party.url.str.contains(all_cookie_values, regex=True) | http_requests_third_party.referrer.str.contains(all_cookie_values, regex=True)]

cookie_syncs = data[data.url.str.contains(cookie_values_string, regex=True)]
cookie_syncs['share_fp_cookie'] = data.url.str.contains(cookie_fp_string, regex=True)
cookie_syncs['share_tp_cookie'] = data.url.str.contains(cookie_tp_string, regex=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# # Full table (both first party and third party)
cookie_syncs = cookie_syncs.reset_index(drop = True)

# %%
cookie_syncs[cookie_syncs.share_fp_cookie].reset_index(drop = True)
# Out:
#     origin_site                            host                     referrer  \
# 0         webmd    dyv1bugovvq1g.cloudfront.net                www.webmd.com
# 1         webmd        sb.scorecardresearch.com                www.webmd.com
# 2         webmd                  s.tagsrvcs.com                www.webmd.com
# 3         webmd        sb.scorecardresearch.com                www.webmd.com
# 4         webmd                  mb.moatads.com                www.webmd.com
# ..          ...                             ...                          ...
# 267     nytimes               stags.bluekai.com              www.nytimes.com
# 268     nytimes            adservice.google.com  5290727.fls.doubleclick.net
# 269     nytimes  securepubads.g.doubleclick.net              www.nytimes.com
# 270     nytimes  securepubads.g.doubleclick.net              www.nytimes.com
# 271     nytimes           cookiex.ngd.yahoo.com       eus.rubiconproject.com
#
#      referred_by_third                                                url  \
# 0                False  https://dyv1bugovvq1g.cloudfront.net/25/www.we...
# 1                False  https://sb.scorecardresearch.com/b?c1=2&c2=603...
# 2                False  https://s.tagsrvcs.com/2/587654/analytics.js?p...
# 3                False  https://sb.scorecardresearch.com/b2?c1=2&c2=60...
# 4                False  https://mb.moatads.com/yi.js?ud=1&qn=%604%7BZE...
# ..                 ...                                                ...
# 267              False  https://stags.bluekai.com/site/50136?limit=1&i...
# 268               True  https://adservice.google.com/ddm/fls/z/src=529...
# 269              False  https://securepubads.g.doubleclick.net/gampad/...
# 270              False  https://securepubads.g.doubleclick.net/gampad/...
# 271               True  https://cookiex.ngd.yahoo.com/ack?xid=p.Jms4Yn...
#
#                                                cookies  share_fp_cookie  \
# 0                                                                  True
# 1                                                                  True
# 2                                                                  True
# 3    UID=12E18428a36a38a281b392c1606506584; UIDR=16...             True
# 4                                                                  True
# ..                                                 ...              ...
# 267                     bkdc=phx; bku=5LD99cNjyPI0ZERF             True
# 268  NID=204=yMh99bQ9AG11gArh5VZA32ANpUgvui-T9uZOxW...             True
# 269  IDE=AHWqTUli2Ug4RelkdVQsl6mdMiY18CRQy0CVBjgL0Z...             True
# 270  IDE=AHWqTUli2Ug4RelkdVQsl6mdMiY18CRQy0CVBjgL0Z...             True
# 271  A3=d=AQABBIdZwV8CEAePsjTU5cRNE7tmBgFkr9IFEgEBA...             True
#
#      share_tp_cookie
# 0              False
# 1               True
# 2              False
# 3               True
# 4              False
# ..               ...
# 267            False
# 268            False
# 269             True
# 270             True
# 271             True
#
# [272 rows x 8 columns]

# %%
# firsty party cookie syncing activity (only requests referred by third party domain)
cookie_syncs[cookie_syncs.share_fp_cookie & cookie_syncs.referred_by_third].reset_index(drop = True)
# Out:
#    origin_site                      host                     referrer  \
# 0        webmd  pixel-sync.sitescout.com     ssum-sec.casalemedia.com
# 1        webmd               i.liadm.com                  i.liadm.com
# 2        webmd     cookiex.ngd.yahoo.com       eus.rubiconproject.com
# 3        webmd      inv-nets.admixer.net         contextual.media.net
# 4        webmd            gum.criteo.com               gum.criteo.com
# 5        webmd          www.facebook.com             www.facebook.com
# 6        webmd         p.adsymptotic.com             ads.pubmatic.com
# 7        webmd             em.licasd.com                  i.liadm.com
# 8        webmd            gum.criteo.com               gum.criteo.com
# 9        webmd        match.prod.bidr.io                  i.liadm.com
# 10       webmd        match.prod.bidr.io                  i.liadm.com
# 11       webmd            gum.criteo.com               gum.criteo.com
# 12       webmd          www.facebook.com             www.facebook.com
# 13     nytimes      adservice.google.com  5290727.fls.doubleclick.net
# 14     nytimes     cookiex.ngd.yahoo.com       eus.rubiconproject.com
#
#     referred_by_third                                                url  \
# 0                True  https://pixel-sync.sitescout.com/dmp/pixelSync...
# 1                True  https://i.liadm.com/s/e/a-00xm/0/4658be9f3b884...
# 2                True  https://cookiex.ngd.yahoo.com/ack?xid=hTHA3OJw...
# 3                True  https://inv-nets.admixer.net/adxcm.aspx?ssp=D4...
# 4                True  https://gum.criteo.com/sid/json?origin=rtus&do...
# 5                True  https://www.facebook.com/platform/plugin/tab/r...
# 6                True  https://p.adsymptotic.com/d/px?_pid=10291&_psi...
# 7                True  https://em.licasd.com/s?l=cc96dcdb-aca1-4198-a...
# 8                True  https://gum.criteo.com/sid/json?origin=rtus&do...
# 9                True  https://match.prod.bidr.io/cookie-sync/liveintent
# 10               True  https://match.prod.bidr.io/cookie-sync/liveint...
# 11               True  https://gum.criteo.com/sid/json?origin=rtus&do...
# 12               True  https://www.facebook.com/platform/plugin/tab/r...
# 13               True  https://adservice.google.com/ddm/fls/z/src=529...
# 14               True  https://cookiex.ngd.yahoo.com/ack?xid=p.Jms4Yn...
#
#                                               cookies  share_fp_cookie  \
# 0   ssi=b88b91ef-ad81-4e06-8d7b-8209bc57e509#16065...             True
# 1   _li_ss=MgUIBhCPDjIFCAoQjw4yBQh6EI4OMgYIiwEQjw4...             True
# 2   A3=d=AQABBF1YwV8CEJA2DW4Mr1L22fxCjYivhF8FEgEBA...             True
# 3                                                                 True
# 4                                                                 True
# 5          fr=0tq2xRdwGaoQ7d6ty..BfwVha...1.0.BfwVha.             True
# 6                  U=e1868f0bb69d8dc2e5b271a71a9cddbe             True
# 7                                                                 True
# 8                                                                 True
# 9                                                                 True
# 10                              checkForPermission=ok             True
# 11                                                                True
# 12         fr=0tq2xRdwGaoQ7d6ty..BfwVha...1.0.BfwVha.             True
# 13  NID=204=yMh99bQ9AG11gArh5VZA32ANpUgvui-T9uZOxW...             True
# 14  A3=d=AQABBIdZwV8CEAePsjTU5cRNE7tmBgFkr9IFEgEBA...             True
#
#     share_tp_cookie
# 0             False
# 1              True
# 2              True
# 3              True
# 4             False
# 5             False
# 6              True
# 7              True
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14             True

# %%
cookie_syncs[cookie_syncs.share_tp_cookie].reset_index(drop = True)
# Out:
#     origin_site                      host                referrer  \
# 0         webmd            dpm.demdex.net           www.webmd.com
# 1         webmd  sb.scorecardresearch.com           www.webmd.com
# 2         webmd            dpm.demdex.net           www.webmd.com
# 3         webmd  sb.scorecardresearch.com           www.webmd.com
# 4         webmd            px.moatads.com           www.webmd.com
# ..          ...                       ...                     ...
# 213     nytimes  pixel.rubiconproject.com  eus.rubiconproject.com
# 214     nytimes             ads.yahoo.com  eus.rubiconproject.com
# 215     nytimes  pixel.rubiconproject.com  eus.rubiconproject.com
# 216     nytimes     s.amazon-adsystem.com
# 217     nytimes     cookiex.ngd.yahoo.com  eus.rubiconproject.com
#
#      referred_by_third                                                url  \
# 0                False  https://dpm.demdex.net/id?d_visid_ver=4.5.2&d_...
# 1                False  https://sb.scorecardresearch.com/b?c1=2&c2=603...
# 2                False  https://dpm.demdex.net/id/rd?d_visid_ver=4.5.2...
# 3                False  https://sb.scorecardresearch.com/b2?c1=2&c2=60...
# 4                False  https://px.moatads.com/pixel.gif?e=17&t=160650...
# ..                 ...                                                ...
# 213               True  https://pixel.rubiconproject.com/tap.php?v=898...
# 214               True  https://ads.yahoo.com/cms/v1?nwid=10000010181&...
# 215               True  https://pixel.rubiconproject.com/tap.php?v=422...
# 216               True  https://s.amazon-adsystem.com/ecm3?id=34949062...
# 217               True  https://cookiex.ngd.yahoo.com/ack?xid=p.Jms4Yn...
#
#                                                cookies  share_fp_cookie  \
# 0                                                                 False
# 1                                                                  True
# 2        demdex=43866217718121268141481295148017842948            False
# 3    UID=12E18428a36a38a281b392c1606506584; UIDR=16...             True
# 4                                                                 False
# ..                                                 ...              ...
# 213  khaos=KI0OPTTN-1I-L1MQ; audit=1|BZZ8oNzhrJA1Lr...            False
# 214                                                               False
# 215  khaos=KI0OPTTN-1I-L1MQ; audit=1|BZZ8oNzhrJA1Lr...            False
# 216        ad-id=A7Vtk8xGAE4RoZw-YGFBwXo; ad-privacy=0            False
# 217  A3=d=AQABBIdZwV8CEAePsjTU5cRNE7tmBgFkr9IFEgEBA...             True
#
#      share_tp_cookie
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ..               ...
# 213             True
# 214             True
# 215             True
# 216             True
# 217             True
#
# [218 rows x 8 columns]

# %%
# third party cookie syncing activity (only requests referred by third party domain)
cookie_syncs[cookie_syncs.share_tp_cookie & cookie_syncs.referred_by_third].reset_index(drop = True)
# Out:
#     origin_site                      host                  referrer  \
# 0         webmd      cm.g.doubleclick.net  ssum-sec.casalemedia.com
# 1         webmd          match.adsrvr.org  ssum-sec.casalemedia.com
# 2         webmd     s.amazon-adsystem.com  ssum-sec.casalemedia.com
# 3         webmd   ups.analytics.yahoo.com  ssum-sec.casalemedia.com
# 4         webmd     s.amazon-adsystem.com  ssum-sec.casalemedia.com
# ..          ...                       ...                       ...
# 125     nytimes  pixel.rubiconproject.com    eus.rubiconproject.com
# 126     nytimes             ads.yahoo.com    eus.rubiconproject.com
# 127     nytimes  pixel.rubiconproject.com    eus.rubiconproject.com
# 128     nytimes     s.amazon-adsystem.com
# 129     nytimes     cookiex.ngd.yahoo.com    eus.rubiconproject.com
#
#      referred_by_third                                                url  \
# 0                 True  https://cm.g.doubleclick.net/pixel?google_nid=...
# 1                 True  https://match.adsrvr.org/track/cmf/casale?cm_u...
# 2                 True  https://s.amazon-adsystem.com/dcm?pid=78af914c...
# 3                 True  https://ups.analytics.yahoo.com/ups/55940/sync...
# 4                 True  https://s.amazon-adsystem.com/ecm3?ex=index.co...
# ..                 ...                                                ...
# 125               True  https://pixel.rubiconproject.com/tap.php?v=898...
# 126               True  https://ads.yahoo.com/cms/v1?nwid=10000010181&...
# 127               True  https://pixel.rubiconproject.com/tap.php?v=422...
# 128               True  https://s.amazon-adsystem.com/ecm3?id=34949062...
# 129               True  https://cookiex.ngd.yahoo.com/ack?xid=p.Jms4Yn...
#
#                                                cookies  share_fp_cookie  \
# 0    IDE=AHWqTUk5UiBOU0d2HbTSKf5GKEa93JnaoAS65cMmKz...            False
# 1    TDID=a9fd6414-644c-43cc-a830-07f62ae7204d; TDC...            False
# 2          ad-id=A9y_eemhaE1wgn6djABN3so; ad-privacy=0            False
# 3    A3=d=AQABBF1YwV8CEJA2DW4Mr1L22fxCjYivhF8FEgEBA...            False
# 4          ad-id=A9y_eemhaE1wgn6djABN3so; ad-privacy=0            False
# ..                                                 ...              ...
# 125  khaos=KI0OPTTN-1I-L1MQ; audit=1|BZZ8oNzhrJA1Lr...            False
# 126                                                               False
# 127  khaos=KI0OPTTN-1I-L1MQ; audit=1|BZZ8oNzhrJA1Lr...            False
# 128        ad-id=A7Vtk8xGAE4RoZw-YGFBwXo; ad-privacy=0            False
# 129  A3=d=AQABBIdZwV8CEAePsjTU5cRNE7tmBgFkr9IFEgEBA...             True
#
#      share_tp_cookie
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ..               ...
# 125             True
# 126             True
# 127             True
# 128             True
# 129             True
#
# [130 rows x 8 columns]

# %%
# filter conditions:
# share_tp_cookie
# referred_by_third
# empty cookie string
cookie_syncs[cookie_syncs.share_tp_cookie & cookie_syncs.referred_by_third & (cookie_syncs.cookies=="")].reset_index(drop = True)
# Out:
#    origin_site                           host  \
# 0        webmd                  cm.smadex.com
# 1        webmd              x.dlx.addthis.com
# 2        webmd               ads.pubmatic.com
# 3        webmd               ads.pubmatic.com
# 4        webmd           inv-nets.admixer.net
# 5        webmd             visitor.fiftyt.com
# 6        webmd           pixel.onaudience.com
# 7        webmd  pagead2.googlesyndication.com
# 8        webmd  pagead2.googlesyndication.com
# 9        webmd  pagead2.googlesyndication.com
# 10       webmd  pagead2.googlesyndication.com
# 11       webmd  pagead2.googlesyndication.com
# 12       webmd  pagead2.googlesyndication.com
# 13       webmd  pagead2.googlesyndication.com
# 14       webmd  pagead2.googlesyndication.com
# 15       webmd  pagead2.googlesyndication.com
# 16       webmd  pagead2.googlesyndication.com
# 17       webmd  pagead2.googlesyndication.com
# 18       webmd  pagead2.googlesyndication.com
# 19       webmd  pagead2.googlesyndication.com
# 20       webmd  pagead2.googlesyndication.com
# 21       webmd  pagead2.googlesyndication.com
# 22       webmd  pagead2.googlesyndication.com
# 23       webmd                  mid.rkdms.com
# 24       webmd              stags.bluekai.com
# 25       webmd                    aa.agkn.com
# 26       webmd                  em.licasd.com
# 27       webmd                live.rezync.com
# 28       webmd                     pippio.com
# 29  mayoclinic           bam-cell.nr-data.net
# 30     nytimes                   ib.adnxs.com
# 31     nytimes                 us-u.openx.net
# 32     nytimes           cm.g.doubleclick.net
# 33     nytimes      medianet-match.dotomi.com
# 34     nytimes                    ad.turn.com
# 35     nytimes                odr.mookie1.com
# 36     nytimes                  ads.yahoo.com
#
#                                              referrer  referred_by_third  \
# 0                            ssum-sec.casalemedia.com               True
# 1                                         i.liadm.com               True
# 2                                contextual.media.net               True
# 3                                    ads.pubmatic.com               True
# 4                                contextual.media.net               True
# 5                                    ads.pubmatic.com               True
# 6                                    ads.pubmatic.com               True
# 7   9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 8   9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 9   9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 10  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 11  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 12  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 13  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 14  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 15  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 16  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 17  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 18  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 19  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 20  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 21  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 22  9fa56b9f2db81251d99ed756d6eadcc5.safeframe.goo...               True
# 23                                        i.liadm.com               True
# 24                                        i.liadm.com               True
# 25                                        i.liadm.com               True
# 26                                        i.liadm.com               True
# 27                                        i.liadm.com               True
# 28                                        i.liadm.com               True
# 29                            www.medtargetsystem.com               True
# 30                               contextual.media.net               True
# 31                               contextual.media.net               True
# 32                               contextual.media.net               True
# 33                               contextual.media.net               True
# 34                               contextual.media.net               True
# 35                               contextual.media.net               True
# 36                             eus.rubiconproject.com               True
#
#                                                   url cookies  \
# 0   https://cm.smadex.com/sync?sm_did=bds&bds_ssp_...
# 1   https://x.dlx.addthis.com/e/live_intent_sync?n...
# 2   https://ads.pubmatic.com/AdServer/js/user_sync...
# 3   https://ads.pubmatic.com/AdServer/js/showad.js...
# 4   https://inv-nets.admixer.net/adxcm.aspx?ssp=D4...
# 5   https://visitor.fiftyt.com/p.gif?ev=sync&p=pm&...
# 6   https://pixel.onaudience.com/?partner=214&mapp...
# 7   https://pagead2.googlesyndication.com/pcs/acti...
# 8   https://pagead2.googlesyndication.com/pcs/acti...
# 9   https://pagead2.googlesyndication.com/pcs/acti...
# 10  https://pagead2.googlesyndication.com/pcs/acti...
# 11  https://pagead2.googlesyndication.com/pcs/acti...
# 12  https://pagead2.googlesyndication.com/pcs/acti...
# 13  https://pagead2.googlesyndication.com/pcs/acti...
# 14  https://pagead2.googlesyndication.com/pcs/acti...
# 15  https://pagead2.googlesyndication.com/pcs/acti...
# 16  https://pagead2.googlesyndication.com/pcs/acti...
# 17  https://pagead2.googlesyndication.com/pcs/acti...
# 18  https://pagead2.googlesyndication.com/pcs/acti...
# 19  https://pagead2.googlesyndication.com/pcs/acti...
# 20  https://pagead2.googlesyndication.com/pcs/acti...
# 21  https://pagead2.googlesyndication.com/pcs/acti...
# 22  https://pagead2.googlesyndication.com/pcs/acti...
# 23  https://mid.rkdms.com/bct?pid=bcccb40a-06d2-44...
# 24  https://stags.bluekai.com/site/42614?id=cc96dc...
# 25  https://aa.agkn.com/adscores/g.pixel?sid=92122...
# 26  https://em.licasd.com/s?l=cc96dcdb-aca1-4198-a...
# 27  https://live.rezync.com/sync?c=0aa2530f29e4f4a...
# 28  https://pippio.com/api/sync?it=1&pid=500040&iv...
# 29  https://bam-cell.nr-data.net/1/e4ee9200d5?a=47...
# 30  https://ib.adnxs.com/getuid?https%3A%2F%2Fcont...
# 31  https://us-u.openx.net/w/1.0/cm?id=78e2dffc-bb...
# 32  https://cm.g.doubleclick.net/pixel?cs=1&google...
# 33  https://medianet-match.dotomi.com/match/bounce...
# 34  https://ad.turn.com/r/cs?pid=59&redir=https%3A...
# 35  https://odr.mookie1.com/t/v2/sync?tagid=V2_790...
# 36  https://ads.yahoo.com/cms/v1?nwid=10000010181&...
#
#     share_fp_cookie  share_tp_cookie
# 0             False             True
# 1             False             True
# 2             False             True
# 3             False             True
# 4              True             True
# 5             False             True
# 6             False             True
# 7             False             True
# 8             False             True
# 9             False             True
# 10            False             True
# 11            False             True
# 12            False             True
# 13            False             True
# 14            False             True
# 15            False             True
# 16            False             True
# 17            False             True
# 18            False             True
# 19            False             True
# 20            False             True
# 21            False             True
# 22            False             True
# 23            False             True
# 24            False             True
# 25            False             True
# 26             True             True
# 27            False             True
# 28            False             True
# 29            False             True
# 30            False             True
# 31            False             True
# 32            False             True
# 33            False             True
# 34            False             True
# 35            False             True
# 36            False             True
