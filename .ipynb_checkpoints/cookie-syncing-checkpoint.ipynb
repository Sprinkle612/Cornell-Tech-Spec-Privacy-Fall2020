# %%
import numpy as np
import pandas as pd
import sqlite3
import sys
import os
import re
from urllib.parse import urlparse

# %%
# helper functions
def get_host_from_headers(x):
    temp = x.replace('"','').split('],[')
    for t in temp:
            pair = t.replace(']]','').replace('[[','').split(',')
            if "Host" in pair:
                host_value = pair[1]
    return host_value

def get_cookies_from_headers(x):
    ls = x.replace('"','').split('],[')
    for l in ls:
        ta = l.replace(']]','').split(',')
        if "Cookie" in ta:
            return ta[-1]
    return ''
def extract_host_from_url(url_ls):
    return list(map(lambda x: urlparse(x).netloc.split('.')[1] if len(urlparse(x).netloc.split('.')) > 1 else x, url_ls))

def get_site(site_url):
    return site_url.split(".")[1]

def is_third_party(origin, url_host):
    if origin in url_host:
        return False
    return True

def save_df_to_csv(df, file_name):
    df.to_csv(file_name+'.csv', index=False)

def extract_deep_clean_host(url):
    s = url.strip(".au").strip('.uk')
    return s.split('.')[-2] if len(s.split('.')) > 1 else s

# %%
data_path = 'exp-data/'
file_name = "nyt-t1"
sql_file = data_path + file_name + '.sqlite'

# %%
query = """SELECT sv.site_url, sv.visit_id,
        hr.headers, hr.referrer, hr.url
        FROM http_requests as hr LEFT JOIN site_visits as sv
        ON sv.visit_id = hr.visit_id
        """
# query = """SELECT sv.site_url, sv.visit_id,
#         hr.headers, hr.referrer, hr.url, hr.top_level_url
#         FROM http_requests as hr LEFT JOIN site_visits as sv
#         ON sv.visit_id = hr.visit_id
#         """

# %%
conn = sqlite3.connect(sql_file)
http_requests = pd.read_sql_query(query, conn)

# %%
http_requests["host"] = list(map(lambda x: get_host_from_headers(x), http_requests.headers.tolist()))
http_requests["cookies"] =  list(map(lambda x: get_cookies_from_headers(x), http_requests.headers.tolist()))
http_requests["origin_site"] = list(map(lambda x: get_site(x), http_requests.site_url))
http_requests["is_third_party"] = list(map(lambda a, b: is_third_party(a, b), http_requests.origin_site, http_requests.host))
http_requests['referrer'] = list(map(lambda x: urlparse(x).netloc, http_requests.referrer))
http_requests['referred_by_third'] = list(map(lambda a, b: is_third_party(a, b), http_requests.origin_site, http_requests.referrer))

# %%
data = http_requests[http_requests.is_third_party == True][["origin_site", \
                                                            "host", "referrer", "referred_by_third", "url", "cookies"]].reset_index(drop = True)

# %%
data
# Out:
#      origin_site                          host  \
# 0          webmd           assets.adobedtm.com
# 1          webmd                  s.flocdn.com
# 2          webmd      www.googleadservices.com
# 3          webmd          fonts.googleapis.com
# 4          webmd  dyv1bugovvq1g.cloudfront.net
# ...          ...                           ...
# 2571     nytimes                   s0.2mdn.net
# 2572     nytimes                   s0.2mdn.net
# 2573     nytimes                   s0.2mdn.net
# 2574     nytimes        dt.adsafeprotected.com
# 2575     nytimes             stags.bluekai.com
#
#                                                referrer  referred_by_third  \
# 0                                         www.webmd.com              False
# 1                                         www.webmd.com              False
# 2                                         www.webmd.com              False
# 3                                         css.webmd.com              False
# 4                                         www.webmd.com              False
# ...                                                 ...                ...
# 2571                                        s0.2mdn.net               True
# 2572                                        s0.2mdn.net               True
# 2573                                        s0.2mdn.net               True
# 2574  eb6611b34a41a87fee3f06cd0e100508.safeframe.goo...               True
# 2575                                  stags.bluekai.com               True
#
#                                                     url  \
# 0     https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 1     https://s.flocdn.com/@s1/embedded-search/embed...
# 2     https://www.googleadservices.com/pagead/conver...
# 3     https://fonts.googleapis.com/css?family=Roboto...
# 4     https://dyv1bugovvq1g.cloudfront.net/25/www.we...
# ...                                                 ...
# 2571  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2572  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2573  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2574  https://dt.adsafeprotected.com/dt?advEntityId=...
# 2575  https://stags.bluekai.com/site/50134?ret=html&...
#
#                              cookies
# 0
# 1
# 2
# 3
# 4
# ...                              ...
# 2571
# 2572
# 2573
# 2574
# 2575  bkdc=phx; bku=5LD99nOUyPI+cnRG
#
# [2576 rows x 6 columns]

# %%
# all entries are referred by third party
# data[data.referred_by_third]

# %%
query2 = """SELECT sv.site_url, sv.visit_id,
        jsc.host, jsc.name, jsc.value
        FROM javascript_cookies as jsc LEFT JOIN site_visits as sv
        ON sv.visit_id = jsc.visit_id
        """
cookies = pd.read_sql_query(query2, conn)

# %%
cookies['origin_site'] = list(map(lambda x: get_site(x), cookies.site_url))
cookies['is_third_party'] = list(map(lambda a, b: is_third_party(a, b), cookies.origin_site, cookies.host))

# %%
cookies_data = cookies[["origin_site", "host", "name", "value", "is_third_party"]]
cookies_data
# Out:
#      origin_site               host       name  \
# 0          webmd     .www.webmd.com   __cfduid
# 1          webmd      .js.webmd.com   __cfduid
# 2          webmd     .img.webmd.com   __cfduid
# 3          webmd     .css.webmd.com   __cfduid
# 4          webmd         .webmd.com       test
# ...          ...                ...        ...
# 2148     nytimes       .bluekai.com        bku
# 2149     nytimes       .bluekai.com        bku
# 2150     nytimes      .pubmatic.com         pi
# 2151     nytimes  .ads.pubmatic.com  PMFREQ_ON
# 2152     nytimes  .ads.pubmatic.com  PMFREQ_ON
#
#                                             value  is_third_party
# 0     de1f86f9e699cddfc6fcaeed623176bae1606506089           False
# 1     d8d4ebd1e437ddcb310e31be0d82e1cdb1606506089           False
# 2     d5b4e59d78d86d6c5ab29b6c3e948cd431606506089           False
# 3     d74794a4d59fa87e1456c8b173f3ff20e1606506089           False
# 4                                          cookie           False
# ...                                           ...             ...
# 2148                             5LD99nOUyPI+cnRG            True
# 2149                             5LD99nOUyPI+cnRG            True
# 2150                                     156011:2            True
# 2151                                          YES            True
# 2152                                          YES            True
#
# [2153 rows x 5 columns]

# %%
cookie_fp = [re.escape(v) for v in set(cookies_data[cookies_data.is_third_party == False].value) if len(v) > 5]
cookie_tp = [re.escape(v) for v in set(cookies_data[cookies_data.is_third_party == True].value) if len(v) > 5]

cookie_fp_string = "|".join(cookie_fp)
cookie_tp_string = "|".join(cookie_tp)

# %%
cookie_values = [re.escape(v) for v in set(cookies.value) if len(v) > 5]
cookie_values_string = "|".join(cookie_values)

# %%
# len(cookie_values_string)

# %%
# http_requests_syncs = http_requests_third_party[http_requests_third_party.url.str.contains(fp_cookie_values, regex=True)]
# http_requests_syncs = http_requests_third_party[http_requests_third_party.url.str.contains(all_cookie_values, regex=True) | http_requests_third_party.referrer.str.contains(all_cookie_values, regex=True)]

cookie_syncs = data[data.url.str.contains(cookie_values_string, regex=True)]
cookie_syncs['share_fp_cookie'] = data.url.str.contains(cookie_fp_string, regex=True)
cookie_syncs['share_tp_cookie'] = data.url.str.contains(cookie_tp_string, regex=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cookie_syncs.reset_index(drop = True)
# Out:
#     origin_site                           host  \
# 0         webmd   dyv1bugovvq1g.cloudfront.net
# 1         webmd                 dpm.demdex.net
# 2         webmd       sb.scorecardresearch.com
# 3         webmd                 s.tagsrvcs.com
# 4         webmd                 dpm.demdex.net
# ..          ...                            ...
# 604     nytimes           cm.g.doubleclick.net
# 605     nytimes            image2.pubmatic.com
# 606     nytimes  pagead2.googlesyndication.com
# 607     nytimes              p.adsymptotic.com
# 608     nytimes           cm.g.doubleclick.net
#
#                                               referrer  referred_by_third  \
# 0                                        www.webmd.com              False
# 1                                        www.webmd.com              False
# 2                                        www.webmd.com              False
# 3                                        www.webmd.com              False
# 4                                        www.webmd.com              False
# ..                                                 ...                ...
# 604                        googleads.g.doubleclick.net               True
# 605                                   ads.pubmatic.com               True
# 606  eb6611b34a41a87fee3f06cd0e100508.safeframe.goo...               True
# 607                                   ads.pubmatic.com               True
# 608                      pagead2.googlesyndication.com               True
#
#                                                    url  \
# 0    https://dyv1bugovvq1g.cloudfront.net/25/www.we...
# 1    https://dpm.demdex.net/id?d_visid_ver=4.5.2&d_...
# 2    https://sb.scorecardresearch.com/b?c1=2&c2=603...
# 3    https://s.tagsrvcs.com/2/587654/analytics.js?p...
# 4    https://dpm.demdex.net/id/rd?d_visid_ver=4.5.2...
# ..                                                 ...
# 604  https://cm.g.doubleclick.net/pixel?google_nid=...
# 605  https://image2.pubmatic.com/AdServer/Pug?vcode...
# 606  https://pagead2.googlesyndication.com/pagead/s...
# 607  https://p.adsymptotic.com/d/px?_pid=10291&_psi...
# 608  https://cm.g.doubleclick.net/pixel?google_nid=...
#
#                                                cookies  share_fp_cookie  \
# 0                                                                  True
# 1                                                                 False
# 2                                                                  True
# 3                                                                  True
# 4        demdex=45429554768808693152241494766003155399            False
# ..                                                 ...              ...
# 604  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...            False
# 605  KTPCACOOKIE=YES; pi=156011:2; KADUSERCOOKIE=7F...            False
# 606                                                                True
# 607                 U=8404820d8b2b85b7e285c2b1d4449fa0            False
# 608  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...            False
#
#      share_tp_cookie
# 0              False
# 1               True
# 2               True
# 3              False
# 4               True
# ..               ...
# 604             True
# 605             True
# 606            False
# 607             True
# 608             True
#
# [609 rows x 8 columns]

# %%
cookie_syncs[cookie_syncs.share_fp_cookie].reset_index(drop = True)
# Out:
#     origin_site                            host  \
# 0         webmd    dyv1bugovvq1g.cloudfront.net
# 1         webmd        sb.scorecardresearch.com
# 2         webmd                  s.tagsrvcs.com
# 3         webmd        sb.scorecardresearch.com
# 4         webmd                  mb.moatads.com
# ..          ...                             ...
# 357     nytimes  securepubads.g.doubleclick.net
# 358     nytimes  securepubads.g.doubleclick.net
# 359     nytimes           cookiex.ngd.yahoo.com
# 360     nytimes               p.adsymptotic.com
# 361     nytimes   pagead2.googlesyndication.com
#
#                                               referrer  referred_by_third  \
# 0                                        www.webmd.com              False
# 1                                        www.webmd.com              False
# 2                                        www.webmd.com              False
# 3                                        www.webmd.com              False
# 4                                        www.webmd.com              False
# ..                                                 ...                ...
# 357                                    www.nytimes.com              False
# 358                                    www.nytimes.com              False
# 359                             eus.rubiconproject.com               True
# 360                                   ads.pubmatic.com               True
# 361  eb6611b34a41a87fee3f06cd0e100508.safeframe.goo...               True
#
#                                                    url  \
# 0    https://dyv1bugovvq1g.cloudfront.net/25/www.we...
# 1    https://sb.scorecardresearch.com/b?c1=2&c2=603...
# 2    https://s.tagsrvcs.com/2/587654/analytics.js?p...
# 3    https://sb.scorecardresearch.com/b2?c1=2&c2=60...
# 4    https://mb.moatads.com/yi.js?ud=1&qn=%604%7BZE...
# ..                                                 ...
# 357  https://securepubads.g.doubleclick.net/gampad/...
# 358  https://securepubads.g.doubleclick.net/gampad/...
# 359  https://cookiex.ngd.yahoo.com/ack?xid=4.FSGr1x...
# 360  https://p.adsymptotic.com/d/px?_pid=10291&_psi...
# 361  https://pagead2.googlesyndication.com/pagead/s...
#
#                                                cookies  share_fp_cookie  \
# 0                                                                  True
# 1                                                                  True
# 2                                                                  True
# 3    UID=16F18428a36a38a2808d1cc1606506090; UIDR=16...             True
# 4                                                                  True
# ..                                                 ...              ...
# 357  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...             True
# 358  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...             True
# 359  A3=d=AQABBLVXwV8CEO2CuGwdUrBvVWgkVOVIuUIFEgEBA...             True
# 360                 U=8404820d8b2b85b7e285c2b1d4449fa0             True
# 361                                                                True
#
#      share_tp_cookie
# 0              False
# 1               True
# 2              False
# 3               True
# 4              False
# ..               ...
# 357             True
# 358             True
# 359             True
# 360             True
# 361            False
#
# [362 rows x 8 columns]

# %%
cookie_syncs[cookie_syncs.share_fp_cookie & cookie_syncs.referred_by_third].reset_index(drop = True)
# Out:
#    origin_site                           host  \
# 0        webmd                 gum.criteo.com
# 1        webmd              p.adsymptotic.com
# 2        webmd       pixel-sync.sitescout.com
# 3        webmd             match.prod.bidr.io
# 4        webmd             match.prod.bidr.io
# 5        webmd          cookiex.ngd.yahoo.com
# 6        webmd                  em.licasd.com
# 7        webmd                 gum.criteo.com
# 8        webmd                 gum.criteo.com
# 9        webmd             match.prod.bidr.io
# 10       webmd                 gum.criteo.com
# 11       webmd  pagead2.googlesyndication.com
# 12       webmd             match.prod.bidr.io
# 13       webmd             match.prod.bidr.io
# 14       webmd              bh.contextweb.com
# 15       webmd             match.prod.bidr.io
# 16       webmd    rtb-csync.smartadserver.com
# 17       webmd             match.prod.bidr.io
# 18       webmd       sync.technoratimedia.com
# 19       webmd             match.prod.bidr.io
# 20       webmd                 gum.criteo.com
# 21       webmd                 gum.criteo.com
# 22  mayoclinic  pagead2.googlesyndication.com
# 23  mayoclinic                  c1.adform.net
# 24  mayoclinic                    bttrack.com
# 25  mayoclinic                  c1.adform.net
# 26  mayoclinic       pixel-sync.sitescout.com
# 27  mayoclinic                  c1.adform.net
# 28  mayoclinic          cookiex.ngd.yahoo.com
# 29  mayoclinic           sync.ipredictive.com
# 30  mayoclinic             match.prod.bidr.io
# 31  mayoclinic                    bttrack.com
# 32  mayoclinic              p.adsymptotic.com
# 33  mayoclinic             match.prod.bidr.io
# 34  mayoclinic           sync.ipredictive.com
# 35  mayoclinic                  c1.adform.net
# 36  mayoclinic                  c1.adform.net
# 37  mayoclinic               sync.adotmob.com
# 38     nytimes           adservice.google.com
# 39     nytimes          cookiex.ngd.yahoo.com
# 40     nytimes              p.adsymptotic.com
# 41     nytimes  pagead2.googlesyndication.com
#
#                                              referrer  referred_by_third  \
# 0                                      gum.criteo.com               True
# 1                                    ads.pubmatic.com               True
# 2                                   bh.contextweb.com               True
# 3                                    cdn.districtm.io               True
# 4                                    cdn.districtm.io               True
# 5                              eus.rubiconproject.com               True
# 6                                         i.liadm.com               True
# 7                                      gum.criteo.com               True
# 8                                      gum.criteo.com               True
# 9                                         i.liadm.com               True
# 10                                     gum.criteo.com               True
# 11  f810978219d81b0254df796d03c8b01e.safeframe.goo...               True
# 12                                   ads.pubmatic.com               True
# 13                                   ads.pubmatic.com               True
# 14                                   ads.pubmatic.com               True
# 15                                   ads.pubmatic.com               True
# 16                                   ads.pubmatic.com               True
# 17                                   ads.pubmatic.com               True
# 18                                   ads.pubmatic.com               True
# 19                                   ads.pubmatic.com               True
# 20                                     gum.criteo.com               True
# 21                                     gum.criteo.com               True
# 22  8fdbd2bc32991e2306b8f719f90b9be4.safeframe.goo...               True
# 23                                      eb2.3lift.com               True
# 24                                      eb2.3lift.com               True
# 25                                      eb2.3lift.com               True
# 26                                      eb2.3lift.com               True
# 27                                      eb2.3lift.com               True
# 28                             eus.rubiconproject.com               True
# 29                                      eb2.3lift.com               True
# 30                           ssum-sec.casalemedia.com               True
# 31                           ssum-sec.casalemedia.com               True
# 32                                      eb2.3lift.com               True
# 33                           ssum-sec.casalemedia.com               True
# 34                             eus.rubiconproject.com               True
# 35                             eus.rubiconproject.com               True
# 36                           ssum-sec.casalemedia.com               True
# 37                             eus.rubiconproject.com               True
# 38                        5290727.fls.doubleclick.net               True
# 39                             eus.rubiconproject.com               True
# 40                                   ads.pubmatic.com               True
# 41  eb6611b34a41a87fee3f06cd0e100508.safeframe.goo...               True
#
#                                                   url  \
# 0   https://gum.criteo.com/sid/json?origin=rtus&do...
# 1   https://p.adsymptotic.com/d/px?_pid=10291&_psi...
# 2   https://pixel-sync.sitescout.com/dmp/pixelSync...
# 3    https://match.prod.bidr.io/cookie-sync/districtm
# 4   https://match.prod.bidr.io/cookie-sync/distric...
# 5   https://cookiex.ngd.yahoo.com/ack?xid=lejC.wIn...
# 6   https://em.licasd.com/s?l=c3615784-b77a-4d21-b...
# 7   https://gum.criteo.com/sid/json?origin=rtus&do...
# 8   https://gum.criteo.com/sid/json?origin=rtus&do...
# 9   https://match.prod.bidr.io/cookie-sync/liveintent
# 10  https://gum.criteo.com/sid/json?origin=rtus&do...
# 11  https://pagead2.googlesyndication.com/pagead/s...
# 12  https://match.prod.bidr.io/cookie-sync/pm&gdpr...
# 13  https://match.prod.bidr.io/cookie-sync/adx?bee...
# 14  https://bh.contextweb.com/bh/rtset?do=add&pid=...
# 15  https://match.prod.bidr.io/cookie-sync?bee_syn...
# 16  https://rtb-csync.smartadserver.com/redir?part...
# 17  https://match.prod.bidr.io/cookie-sync?bee_syn...
# 18  https://sync.technoratimedia.com/services?srv=...
# 19  https://match.prod.bidr.io/cookie-sync?userid=...
# 20  https://gum.criteo.com/sid/json?origin=rtus&do...
# 21  https://gum.criteo.com/sid/json?origin=rtus&do...
# 22  https://pagead2.googlesyndication.com/pagead/s...
# 23  https://c1.adform.net/serving/cookie/match?par...
# 24  https://bttrack.com/pixel/cookiesync?source=3a...
# 25  https://c1.adform.net/serving/cookie/match/?pa...
# 26  https://pixel-sync.sitescout.com/dmp/pixelSync...
# 27  https://c1.adform.net/serving/cookie/match?CC=...
# 28  https://cookiex.ngd.yahoo.com/ack?xid=zdghJlsm...
# 29  https://sync.ipredictive.com/d/sync/cookie/gen...
# 30          https://match.prod.bidr.io/cookie-sync/ie
# 31  https://bttrack.com/pixel/cookiesync?source=67...
# 32  https://p.adsymptotic.com/d/px/?_pid=16259&_ps...
# 33  https://match.prod.bidr.io/cookie-sync/ie?_bee...
# 34  https://sync.ipredictive.com/d/sync/cookie/gen...
# 35  https://c1.adform.net/serving/cookie/match?par...
# 36  https://c1.adform.net/serving/cookie/match?par...
# 37            https://sync.adotmob.com/cookie/rubicon
# 38  https://adservice.google.com/ddm/fls/i/src=529...
# 39  https://cookiex.ngd.yahoo.com/ack?xid=4.FSGr1x...
# 40  https://p.adsymptotic.com/d/px?_pid=10291&_psi...
# 41  https://pagead2.googlesyndication.com/pagead/s...
#
#                                               cookies  share_fp_cookie  \
# 0                                                                 True
# 1                  U=fbf29550bfb71972cda64a7d6535fdbb             True
# 2   ssi=4df5df60-3216-4835-b3aa-8840de06bef1#16065...             True
# 3                                                                 True
# 4                               checkForPermission=ok             True
# 5   A3=d=AQABBHFWwV8CEBavED6Nut--YHN9-9sAFrcFEgEBA...             True
# 6                                                                 True
# 7                                                                 True
# 8                                                                 True
# 9        bito=AACsX06_gq0AAA9ws8SYJw; bitoIsSecure=ok             True
# 10                                                                True
# 11                                                                True
# 12       bito=AACsX06_gq0AAA9ws8SYJw; bitoIsSecure=ok             True
# 13       bito=AACsX06_gq0AAA9ws8SYJw; bitoIsSecure=ok             True
# 14  V=5meDYkJL8A9y; pb_rtb_ev=3-13ye|2N.0.AAAGX8gl...             True
# 15       bito=AACsX06_gq0AAA9ws8SYJw; bitoIsSecure=ok             True
# 16                                                                True
# 17       bito=AACsX06_gq0AAA9ws8SYJw; bitoIsSecure=ok             True
# 18                                                                True
# 19       bito=AACsX06_gq0AAA9ws8SYJw; bitoIsSecure=ok             True
# 20                                                                True
# 21                                                                True
# 22                                                                True
# 23                                                                True
# 24                                                                True
# 25                             uid=105076679007401329             True
# 26  ssi=1df992d2-8a2a-499a-beec-be01f7a8f73a#16065...             True
# 27                             uid=105076679007401329             True
# 28  B=comhpo5fs2los&b=3&s=h1; A3=d=AQABBBxXwV8CEJG...             True
# 29                                                                True
# 30                                                                True
# 31  GLOBALID=2uKlc8-sIBd987FnJ4K6HZ_8fnIHJ1OHC3M45...             True
# 32                 U=de01391ed0dfdb49e28a72151e89c4ad             True
# 33                              checkForPermission=ok             True
# 34  cu=19991d3e-30e9-11eb-bd50-670ee043d94f|160650...             True
# 35                             uid=105076679007401329             True
# 36                             uid=105076679007401329             True
# 37                                                                True
# 38  NID=204=D54h98AZvmH89boY4AOEYkgO1Yu0fqMzWQqU7n...             True
# 39  A3=d=AQABBLVXwV8CEO2CuGwdUrBvVWgkVOVIuUIFEgEBA...             True
# 40                 U=8404820d8b2b85b7e285c2b1d4449fa0             True
# 41                                                                True
#
#     share_tp_cookie
# 0             False
# 1              True
# 2             False
# 3             False
# 4             False
# 5              True
# 6              True
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14             True
# 15             True
# 16             True
# 17             True
# 18             True
# 19             True
# 20            False
# 21            False
# 22            False
# 23            False
# 24            False
# 25            False
# 26            False
# 27            False
# 28             True
# 29            False
# 30            False
# 31            False
# 32             True
# 33            False
# 34            False
# 35            False
# 36            False
# 37            False
# 38             True
# 39             True
# 40             True
# 41            False

# %%
# http_requests_syncs[http_requests_syncs.share_tp_cookie].shape

# %%
# http_requests_syncs[http_requests_syncs.referred_by_third & http_requests_syncs.share_tp_cookie].shape

# %%
print(http_requests_syncs[http_requests_syncs.share_fp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.share_fp_cookie & http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie & http_requests_syncs.referred_by_third].shape[0])

# %%
print(http_requests_syncs[http_requests_syncs.share_fp_cookie][http_requests_syncs.cookies==""].shape[0])
print(http_requests_syncs[http_requests_syncs.share_fp_cookie][http_requests_syncs.cookies==""][http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie][http_requests_syncs.cookies==""].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie][http_requests_syncs.cookies==""][http_requests_syncs.referred_by_third].shape[0])

# %%
# http_requests_syncs[http_requests_syncs.is_diff_host & http_requests_syncs.share_tp_cookie].shape

# %%
# only index 3
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_fp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_fp_cookie][http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_tp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_tp_cookie][http_requests_syncs.referred_by_third].shape[0])

# %%
# only index 3
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_fp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_fp_cookie][http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_tp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_tp_cookie][http_requests_syncs.referred_by_third].shape[0])

# %%
# save_df_to_csv(http_requests_syncs, "cookie_syncs_" +file_name)
