# %%
import numpy as np
import pandas as pd
import sqlite3
import sys
import os
import re
from urllib.parse import urlparse

# %%
# helper functions
def get_host_from_headers(x):
    temp = x.replace('"','').split('],[')
    for t in temp:
            pair = t.replace(']]','').replace('[[','').split(',')
            if "Host" in pair:
                host_value = pair[1]
    return host_value

def get_cookies_from_headers(x):
    ls = x.replace('"','').split('],[')
    for l in ls:
        ta = l.replace(']]','').split(',')
        if "Cookie" in ta:
            return ta[-1]
    return ''
def extract_host_from_url(url_ls):
    return list(map(lambda x: urlparse(x).netloc.split('.')[1] if len(urlparse(x).netloc.split('.')) > 1 else x, url_ls))

def get_site(site_url):
    return site_url.split(".")[1]

def is_third_party(origin, url_host):
    if origin in url_host:
        return False
    return True

def save_df_to_csv(df, file_name):
    df.to_csv(file_name+'.csv', index=False)

def extract_deep_clean_host(url):
    s = url.strip(".au").strip('.uk')
    return s.split('.')[-2] if len(s.split('.')) > 1 else s

# %%
data_path = 'exp-data/'
file_name = "nyt-t1"
sql_file = data_path + file_name + '.sqlite'

# %%
query = """SELECT sv.site_url, sv.visit_id,
        hr.headers, hr.referrer, hr.url
        FROM http_requests as hr LEFT JOIN site_visits as sv
        ON sv.visit_id = hr.visit_id
        """
# query = """SELECT sv.site_url, sv.visit_id,
#         hr.headers, hr.referrer, hr.url, hr.top_level_url
#         FROM http_requests as hr LEFT JOIN site_visits as sv
#         ON sv.visit_id = hr.visit_id
#         """

# %%
conn = sqlite3.connect(sql_file)
http_requests = pd.read_sql_query(query, conn)

# %%
http_requests["host"] = list(map(lambda x: get_host_from_headers(x), http_requests.headers.tolist()))
http_requests["cookies"] =  list(map(lambda x: get_cookies_from_headers(x), http_requests.headers.tolist()))
http_requests["origin_site"] = list(map(lambda x: get_site(x), http_requests.site_url))
http_requests["is_third_party"] = list(map(lambda a, b: is_third_party(a, b), http_requests.origin_site, http_requests.host))

# %%
http_requests.shape
# Out:
# (3290, 9)

# %%
data = http_requests[http_requests.is_third_party == True][["origin_site", "host", "referrer", "url", "cookies"]].reset_index(drop = True)

# %%
data
# Out:
#      origin_site                          host  \
# 0          webmd           assets.adobedtm.com
# 1          webmd                  s.flocdn.com
# 2          webmd      www.googleadservices.com
# 3          webmd          fonts.googleapis.com
# 4          webmd  dyv1bugovvq1g.cloudfront.net
# ...          ...                           ...
# 2571     nytimes                   s0.2mdn.net
# 2572     nytimes                   s0.2mdn.net
# 2573     nytimes                   s0.2mdn.net
# 2574     nytimes        dt.adsafeprotected.com
# 2575     nytimes             stags.bluekai.com
#
#                                                referrer  \
# 0     https://www.webmd.com/search/search_results/de...
# 1     https://www.webmd.com/search/search_results/de...
# 2     https://www.webmd.com/search/search_results/de...
# 3     https://css.webmd.com/dtmcms/live/webmd/PageBu...
# 4     https://www.webmd.com/search/search_results/de...
# ...                                                 ...
# 2571  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2572  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2573  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2574  https://eb6611b34a41a87fee3f06cd0e100508.safef...
# 2575  https://stags.bluekai.com/site/50134?ret=html&...
#
#                                                     url  \
# 0     https://assets.adobedtm.com/2c8c1e17b98c/e6d47...
# 1     https://s.flocdn.com/@s1/embedded-search/embed...
# 2     https://www.googleadservices.com/pagead/conver...
# 3     https://fonts.googleapis.com/css?family=Roboto...
# 4     https://dyv1bugovvq1g.cloudfront.net/25/www.we...
# ...                                                 ...
# 2571  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2572  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2573  https://s0.2mdn.net/9847206/1606143779106/4151...
# 2574  https://dt.adsafeprotected.com/dt?advEntityId=...
# 2575  https://stags.bluekai.com/site/50134?ret=html&...
#
#                              cookies
# 0
# 1
# 2
# 3
# 4
# ...                              ...
# 2571
# 2572
# 2573
# 2574
# 2575  bkdc=phx; bku=5LD99nOUyPI+cnRG
#
# [2576 rows x 5 columns]

# %%
query2 = """SELECT sv.site_url, sv.visit_id,
        jsc.host, jsc.name, jsc.value
        FROM javascript_cookies as jsc LEFT JOIN site_visits as sv
        ON sv.visit_id = jsc.visit_id
        """
cookies = pd.read_sql_query(query2, conn)

# %%
cookies
# Out:
#                                                site_url  visit_id  \
# 0     https://www.webmd.com/search/search_results/de...         1
# 1     https://www.webmd.com/search/search_results/de...         1
# 2     https://www.webmd.com/search/search_results/de...         1
# 3     https://www.webmd.com/search/search_results/de...         1
# 4     https://www.webmd.com/search/search_results/de...         1
# ...                                                 ...       ...
# 2148                           https://www.nytimes.com/         3
# 2149                           https://www.nytimes.com/         3
# 2150                           https://www.nytimes.com/         3
# 2151                           https://www.nytimes.com/         3
# 2152                           https://www.nytimes.com/         3
#
#                    host       name  \
# 0        .www.webmd.com   __cfduid
# 1         .js.webmd.com   __cfduid
# 2        .img.webmd.com   __cfduid
# 3        .css.webmd.com   __cfduid
# 4            .webmd.com       test
# ...                 ...        ...
# 2148       .bluekai.com        bku
# 2149       .bluekai.com        bku
# 2150      .pubmatic.com         pi
# 2151  .ads.pubmatic.com  PMFREQ_ON
# 2152  .ads.pubmatic.com  PMFREQ_ON
#
#                                             value
# 0     de1f86f9e699cddfc6fcaeed623176bae1606506089
# 1     d8d4ebd1e437ddcb310e31be0d82e1cdb1606506089
# 2     d5b4e59d78d86d6c5ab29b6c3e948cd431606506089
# 3     d74794a4d59fa87e1456c8b173f3ff20e1606506089
# 4                                          cookie
# ...                                           ...
# 2148                             5LD99nOUyPI+cnRG
# 2149                             5LD99nOUyPI+cnRG
# 2150                                     156011:2
# 2151                                          YES
# 2152                                          YES
#
# [2153 rows x 5 columns]

# %%
cookies['origin_site'] = list(map(lambda x: get_site(x), cookies.site_url))
cookies['is_third_party'] = list(map(lambda a, b: is_third_party(a, b), cookies.origin_site, cookies.host))

# %%
cookies_first_party = cookies[cookies.is_third_party == False]
cookies_third_party = cookies[cookies.is_third_party == True]

# %%
cookie_fp_effective = [re.escape(v) for v in set(cookies_first_party.value) if len(v) > 5]
cookie_tp_effective = [re.escape(v) for v in set(cookies_third_party.value) if len(v) > 5]
cookie_effective_all = [re.escape(v) for v in set(cookies.value) if len(v) > 5]

# %%
fp_cookie_values = "|".join(cookie_fp_effective)
tp_cookie_values = "|".join(cookie_tp_effective)
all_cookie_values = "|".join(cookie_effective_all)

# %%
# len(tp_cookie_values)

# %%
http_requests_third_party.shape
# Out:
# (2576, 10)

# %%
# http_requests_syncs = http_requests_third_party[http_requests_third_party.url.str.contains(fp_cookie_values, regex=True)]
http_requests_syncs = http_requests_third_party[http_requests_third_party.url.str.contains(all_cookie_values, regex=True) | http_requests_third_party.referrer.str.contains(all_cookie_values, regex=True)]

# %%
http_requests_syncs.shape
# Out:
# (1236, 10)

# %%
# a = http_requests_third_party.url.str.contains(fp_cookie_values, regex=True).index
# b = http_requests_third_party[http_requests_third_party.url.str.contains(fp_cookie_values, regex=True)]

# %%
# b

# %%
# b

# %%
http_requests_syncs['share_fp_cookie'] = http_requests_third_party.url.str.contains(fp_cookie_values, regex=True)
http_requests_syncs['share_tp_cookie'] = http_requests_third_party.url.str.contains(tp_cookie_values, regex=True)
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# extract third party
http_requests_syncs['referrer_host'] = list(map(lambda x: urlparse(x).netloc, http_requests_syncs.referrer))
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# can tell wether referrer and url are different
http_requests_syncs['is_diff_host'] = list(map(lambda a, b: a != b, http_requests_syncs.host, http_requests_syncs.referrer_host))
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
http_requests_syncs['referred_by_third'] = list(map(lambda a, b: is_third_party(a, b), http_requests_syncs.origin_site, http_requests_syncs.referrer_host))
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
http_requests_syncs = http_requests_syncs[http_requests_syncs.is_diff_host]
# 609 -> 576

# %%
http_requests_syncs.drop(columns=['site_url', 'headers','visit_id', 'is_diff_host'], inplace=True)
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
http_requests_syncs
# Out:
#                                                referrer  \
# 38    https://www.webmd.com/search/search_results/de...
# 47    https://www.webmd.com/search/search_results/de...
# 51    https://www.webmd.com/search/search_results/de...
# 53    https://www.webmd.com/search/search_results/de...
# 68    https://www.webmd.com/search/search_results/de...
# 69    https://www.webmd.com/search/search_results/de...
# 72    https://www.webmd.com/search/search_results/de...
# 75    https://www.webmd.com/search/search_results/de...
# 81    https://www.webmd.com/search/search_results/de...
# 82    https://www.webmd.com/search/search_results/de...
# 83    https://www.webmd.com/search/search_results/de...
# 91    https://www.webmd.com/search/search_results/de...
# 93    https://www.webmd.com/search/search_results/de...
# 94    https://www.webmd.com/search/search_results/de...
# 100   https://www.webmd.com/search/search_results/de...
# 101   https://www.webmd.com/search/search_results/de...
# 102   https://www.webmd.com/search/search_results/de...
# 104   https://img.webmd.com/pixel/liveramp.a.html?do...
# 112   https://www.webmd.com/search/search_results/de...
# 117                              https://www.webmd.com/
# 118   https://www.webmd.com/search/search_results/de...
# 120   https://www.webmd.com/search/search_results/de...
# 125   https://www.webmd.com/search/search_results/de...
# 126   https://www.webmd.com/search/search_results/de...
# 127   https://www.webmd.com/search/search_results/de...
# 128   https://www.webmd.com/search/search_results/de...
# 130   https://contextual.media.net/checksync.php?&vs...
# 131   https://contextual.media.net/checksync.php?&vs...
# 133   https://contextual.media.net/checksync.php?&vs...
# 135   https://contextual.media.net/checksync.php?&vs...
# ...                                                 ...
# 2953  https://contextual.media.net/checksync.php?&vs...
# 2958                           https://www.nytimes.com/
# 2959  https://contextual.media.net/checksync.php?&vs...
# 2963  https://stags.bluekai.com/site/50134?ret=html&...
# 2971  https://contextual.media.net/checksync.php?&vs...
# 2975                           https://www.nytimes.com/
# 2976                           https://www.nytimes.com/
# 2992  https://eus.rubiconproject.com/usync.html?p=me...
# 3003  https://eus.rubiconproject.com/usync.html?p=me...
# 3010
# 3012  https://eus.rubiconproject.com/usync.html?p=me...
# 3170  https://eus.rubiconproject.com/usync.html?p=me...
# 3178  https://u.openx.net/w/1.0/cm?id=e818ca1e-0c23-...
# 3180
# 3182  https://eus.rubiconproject.com/usync.html?p=me...
# 3198     https://ads.pubmatic.com/AdServer/js/showad.js
# 3199     https://ads.pubmatic.com/AdServer/js/showad.js
# 3206     https://ads.pubmatic.com/AdServer/js/showad.js
# 3210  https://stags.bluekai.com/site/50134?ret=html&...
# 3216  https://eus.rubiconproject.com/usync.html?p=a9...
# 3222     https://ads.pubmatic.com/AdServer/js/showad.js
# 3226     https://ads.pubmatic.com/AdServer/js/showad.js
# 3228     https://ads.pubmatic.com/AdServer/js/showad.js
# 3229     https://ads.pubmatic.com/AdServer/js/showad.js
# 3231     https://ads.pubmatic.com/AdServer/js/showad.js
# 3232  https://googleads.g.doubleclick.net/xbbe/pixel...
# 3239     https://ads.pubmatic.com/AdServer/js/showad.js
# 3240  https://eb6611b34a41a87fee3f06cd0e100508.safef...
# 3250     https://ads.pubmatic.com/AdServer/js/showad.js
# 3264  https://pagead2.googlesyndication.com/pagead/s...
#
#                                                     url  \
# 38    https://dyv1bugovvq1g.cloudfront.net/25/www.we...
# 47    https://dpm.demdex.net/id?d_visid_ver=4.5.2&d_...
# 51    https://sb.scorecardresearch.com/b?c1=2&c2=603...
# 53    https://s.tagsrvcs.com/2/587654/analytics.js?p...
# 68    https://dpm.demdex.net/id/rd?d_visid_ver=4.5.2...
# 69    https://sb.scorecardresearch.com/b2?c1=2&c2=60...
# 72    https://mb.moatads.com/yi.js?ud=1&qn=%604%7BZE...
# 75    https://contextual.media.net/mcx.js?&rt=2&call...
# 81    https://contextual.media.net/rtbsmpubs.php?&gd...
# 82    https://contextual.media.net/rtbsmpubs.php?&gd...
# 83    https://contextual.media.net/rtbsmpubs.php?&gd...
# 91    https://px.moatads.com/pixel.gif?e=17&i=WEBMD_...
# 93    https://contextual.media.net/ruleengine.php?&a...
# 94    https://c.amazon-adsystem.com/e/dtb/bid?src=31...
# 100   https://cslogger.media.net/log?logid=kfk&evtid...
# 101   https://contextual.media.net/rtbsmpubs.php?&gd...
# 102   https://px.moatads.com/pixel.gif?e=0&q=0&hp=1&...
# 104   https://idsync.rlcdn.com/453089.gif?site=https...
# 112   https://rp.liadm.com/j?tna=v2.0.0&aid=a-00xm&w...
# 117   https://rp.liadm.com/j?tna=v2.0.0&aid=a-00xm&w...
# 118   https://lgncal.media.net/log?logid=kfk&evtid=c...
# 120   https://gum.criteo.com/syncframe?topUrl=www.we...
# 125   https://ibclick.stream/csc-event?p=0%3Aki0o8ye...
# 126   https://contextual.media.net/rtbsmpubs.php?&gd...
# 127   https://contextual.media.net/rtbsmpubs.php?&gd...
# 128   https://i.liadm.com/s/c/a-00xm?s=&cim=&ps=true...
# 130   https://ib.adnxs.com/getuid?https%3A%2F%2Fcont...
# 131   https://ads.pubmatic.com/AdServer/js/user_sync...
# 133   https://medianet-match.dotomi.com/match/bounce...
# 135   https://cm.g.doubleclick.net/pixel?cs=1&google...
# ...                                                 ...
# 2953  https://cs.media.net/cksync?cs=1&type=ttd&ovsi...
# 2958  https://www.google.com/ads/ga-audiences?t=sr&a...
# 2959  https://cm.g.doubleclick.net/pixel?google_nid=...
# 2963  https://tags.bluekai.com/site/4538?id=16C1B147...
# 2971  https://x.bidswitch.net/sync?dsp_id=16&user_id...
# 2975  https://securepubads.g.doubleclick.net/gampad/...
# 2976  https://securepubads.g.doubleclick.net/gampad/...
# 2992  https://contextual.media.net/cksync.php?type=r...
# 3003  https://pixel.rubiconproject.com/tap.php?v=898...
# 3010  https://s.amazon-adsystem.com/ecm3?id=34989497...
# 3012  https://ads.yahoo.com/cms/v1?nwid=10000010181&...
# 3170  https://pixel.rubiconproject.com/tap.php?v=422...
# 3178  https://us-u.openx.net/w/1.0/sd?id=537072971&v...
# 3180  https://s.amazon-adsystem.com/ecm3?ex=3lift.co...
# 3182  https://cookiex.ngd.yahoo.com/ack?xid=4.FSGr1x...
# 3198  https://visitor.fiftyt.com/p.gif?ev=sync&p=pm&...
# 3199  https://pixel.onaudience.com/?partner=214&mapp...
# 3206  https://s.amazon-adsystem.com/ecm3?id=7F2423D3...
# 3210  https://tags.bluekai.com/site/4538?id=16C1B147...
# 3216  https://s.amazon-adsystem.com/ecm3?id=KI0OFXCE...
# 3222  https://simage2.pubmatic.com/AdServer/Pug?vcod...
# 3226  https://image2.pubmatic.com/AdServer/Pug?vcode...
# 3228  https://p.adsymptotic.com/d/px?_pid=10291&_psi...
# 3229  https://simage2.pubmatic.com/AdServer/Pug?vcod...
# 3231  https://visitor.fiftyt.com/p.gif?ev=sync&p=pm&...
# 3232  https://cm.g.doubleclick.net/pixel?google_nid=...
# 3239  https://image2.pubmatic.com/AdServer/Pug?vcode...
# 3240  https://pagead2.googlesyndication.com/pagead/s...
# 3250  https://p.adsymptotic.com/d/px?_pid=10291&_psi...
# 3264  https://cm.g.doubleclick.net/pixel?google_nid=...
#
#                                           top_level_url  \
# 38    https://www.webmd.com/search/search_results/de...
# 47    https://www.webmd.com/search/search_results/de...
# 51    https://www.webmd.com/search/search_results/de...
# 53    https://www.webmd.com/search/search_results/de...
# 68    https://www.webmd.com/search/search_results/de...
# 69    https://www.webmd.com/search/search_results/de...
# 72    https://www.webmd.com/search/search_results/de...
# 75    https://www.webmd.com/search/search_results/de...
# 81    https://www.webmd.com/search/search_results/de...
# 82    https://www.webmd.com/search/search_results/de...
# 83    https://www.webmd.com/search/search_results/de...
# 91    https://www.webmd.com/search/search_results/de...
# 93    https://www.webmd.com/search/search_results/de...
# 94    https://www.webmd.com/search/search_results/de...
# 100   https://www.webmd.com/search/search_results/de...
# 101   https://www.webmd.com/search/search_results/de...
# 102   https://www.webmd.com/search/search_results/de...
# 104   https://www.webmd.com/search/search_results/de...
# 112   https://www.webmd.com/search/search_results/de...
# 117   https://www.webmd.com/search/search_results/de...
# 118   https://www.webmd.com/search/search_results/de...
# 120   https://www.webmd.com/search/search_results/de...
# 125   https://www.webmd.com/search/search_results/de...
# 126   https://www.webmd.com/search/search_results/de...
# 127   https://www.webmd.com/search/search_results/de...
# 128   https://www.webmd.com/search/search_results/de...
# 130   https://www.webmd.com/search/search_results/de...
# 131   https://www.webmd.com/search/search_results/de...
# 133   https://www.webmd.com/search/search_results/de...
# 135   https://www.webmd.com/search/search_results/de...
# ...                                                 ...
# 2953                           https://www.nytimes.com/
# 2958                           https://www.nytimes.com/
# 2959                           https://www.nytimes.com/
# 2963                           https://www.nytimes.com/
# 2971                           https://www.nytimes.com/
# 2975                           https://www.nytimes.com/
# 2976                           https://www.nytimes.com/
# 2992                           https://www.nytimes.com/
# 3003                           https://www.nytimes.com/
# 3010                           https://www.nytimes.com/
# 3012                           https://www.nytimes.com/
# 3170                           https://www.nytimes.com/
# 3178                           https://www.nytimes.com/
# 3180                           https://www.nytimes.com/
# 3182                           https://www.nytimes.com/
# 3198                           https://www.nytimes.com/
# 3199                           https://www.nytimes.com/
# 3206                           https://www.nytimes.com/
# 3210                           https://www.nytimes.com/
# 3216                           https://www.nytimes.com/
# 3222                           https://www.nytimes.com/
# 3226                           https://www.nytimes.com/
# 3228                           https://www.nytimes.com/
# 3229                           https://www.nytimes.com/
# 3231                           https://www.nytimes.com/
# 3232                           https://www.nytimes.com/
# 3239                           https://www.nytimes.com/
# 3240                           https://www.nytimes.com/
# 3250                           https://www.nytimes.com/
# 3264                           https://www.nytimes.com/
#
#                                 host  \
# 38      dyv1bugovvq1g.cloudfront.net
# 47                    dpm.demdex.net
# 51          sb.scorecardresearch.com
# 53                    s.tagsrvcs.com
# 68                    dpm.demdex.net
# 69          sb.scorecardresearch.com
# 72                    mb.moatads.com
# 75              contextual.media.net
# 81              contextual.media.net
# 82              contextual.media.net
# 83              contextual.media.net
# 91                    px.moatads.com
# 93              contextual.media.net
# 94             c.amazon-adsystem.com
# 100               cslogger.media.net
# 101             contextual.media.net
# 102                   px.moatads.com
# 104                 idsync.rlcdn.com
# 112                     rp.liadm.com
# 117                     rp.liadm.com
# 118                 lgncal.media.net
# 120                   gum.criteo.com
# 125                   ibclick.stream
# 126             contextual.media.net
# 127             contextual.media.net
# 128                      i.liadm.com
# 130                     ib.adnxs.com
# 131                 ads.pubmatic.com
# 133        medianet-match.dotomi.com
# 135             cm.g.doubleclick.net
# ...                              ...
# 2953                    cs.media.net
# 2958                  www.google.com
# 2959            cm.g.doubleclick.net
# 2963                tags.bluekai.com
# 2971                 x.bidswitch.net
# 2975  securepubads.g.doubleclick.net
# 2976  securepubads.g.doubleclick.net
# 2992            contextual.media.net
# 3003        pixel.rubiconproject.com
# 3010           s.amazon-adsystem.com
# 3012                   ads.yahoo.com
# 3170        pixel.rubiconproject.com
# 3178                  us-u.openx.net
# 3180           s.amazon-adsystem.com
# 3182           cookiex.ngd.yahoo.com
# 3198              visitor.fiftyt.com
# 3199            pixel.onaudience.com
# 3206           s.amazon-adsystem.com
# 3210                tags.bluekai.com
# 3216           s.amazon-adsystem.com
# 3222            simage2.pubmatic.com
# 3226             image2.pubmatic.com
# 3228               p.adsymptotic.com
# 3229            simage2.pubmatic.com
# 3231              visitor.fiftyt.com
# 3232            cm.g.doubleclick.net
# 3239             image2.pubmatic.com
# 3240   pagead2.googlesyndication.com
# 3250               p.adsymptotic.com
# 3264            cm.g.doubleclick.net
#
#                                                 cookies origin_site  \
# 38                                                            webmd
# 47                                                            webmd
# 51                                                            webmd
# 53                                                            webmd
# 68        demdex=45429554768808693152241494766003155399       webmd
# 69    UID=16F18428a36a38a2808d1cc1606506090; UIDR=16...       webmd
# 72                                                            webmd
# 75                    visitor-id=2495076903613114000V10       webmd
# 81                    visitor-id=2495076903613114000V10       webmd
# 82                    visitor-id=2495076903613114000V10       webmd
# 83                    visitor-id=2495076903613114000V10       webmd
# 91                                                            webmd
# 93                    visitor-id=2495076903613114000V10       webmd
# 94                                                            webmd
# 100                   visitor-id=2495076903613114000V10       webmd
# 101                   visitor-id=2495076903613114000V10       webmd
# 102                                                           webmd
# 104                                                           webmd
# 112                                                           webmd
# 117          lidid=c3615784-b77a-4d21-bfc2-bc19665d8947       webmd
# 118                   visitor-id=2495076903613114000V10       webmd
# 120                                                           webmd
# 125   _ibp=0:ki0o8yeo:45b107e5-2209-4665-a24e-435f8a...       webmd
# 126                   visitor-id=2495076903613114000V10       webmd
# 127                   visitor-id=2495076903613114000V10       webmd
# 128          lidid=c3615784-b77a-4d21-bfc2-bc19665d8947       webmd
# 130                                                           webmd
# 131                                                           webmd
# 133                                                           webmd
# 135                                                           webmd
# ...                                                 ...         ...
# 2953                  visitor-id=2495080063613156000V10     nytimes
# 2958  NID=204=D54h98AZvmH89boY4AOEYkgO1Yu0fqMzWQqU7n...     nytimes
# 2959  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...     nytimes
# 2963                     bkdc=phx; bku=5LD99nOUyPI+cnRG     nytimes
# 2971  tuuid=ac654ccd-05e0-467c-845c-c253a8b6cf35; c=...     nytimes
# 2975  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...     nytimes
# 2976  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...     nytimes
# 2992  visitor-id=2495080063613156000V10; data-g=11~~...     nytimes
# 3003  khaos=KI0OFXCE-1Y-LLAW; audit=1|vaQE95Gfff45c/...     nytimes
# 3010        ad-id=A2ehY0EDCEkerr-iD3PH9Gk; ad-privacy=0     nytimes
# 3012  A3=d=AQABBLVXwV8CEO2CuGwdUrBvVWgkVOVIuUIFEgEBA...     nytimes
# 3170  khaos=KI0OFXCE-1Y-LLAW; audit=1|vaQE95Gfff45c/...     nytimes
# 3178  i=11e8535b-9df9-0c82-2ff3-8aae68438c91|1606506...     nytimes
# 3180        ad-id=A2ehY0EDCEkerr-iD3PH9Gk; ad-privacy=0     nytimes
# 3182  A3=d=AQABBLVXwV8CEO2CuGwdUrBvVWgkVOVIuUIFEgEBA...     nytimes
# 3198                                                        nytimes
# 3199                                                        nytimes
# 3206        ad-id=A2ehY0EDCEkerr-iD3PH9Gk; ad-privacy=0     nytimes
# 3210                     bkdc=phx; bku=5LD99nOUyPI+cnRG     nytimes
# 3216        ad-id=A2ehY0EDCEkerr-iD3PH9Gk; ad-privacy=0     nytimes
# 3222  KTPCACOOKIE=YES; pi=156011:2; KADUSERCOOKIE=7F...     nytimes
# 3226  KTPCACOOKIE=YES; pi=156011:2; KADUSERCOOKIE=7F...     nytimes
# 3228                 U=8404820d8b2b85b7e285c2b1d4449fa0     nytimes
# 3229  KTPCACOOKIE=YES; pi=156011:2; KADUSERCOOKIE=7F...     nytimes
# 3231  fifid=1d81ea5a-ba08-4a1c-6960-cf1ee89f9093; cs...     nytimes
# 3232  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...     nytimes
# 3239  KTPCACOOKIE=YES; pi=156011:2; KADUSERCOOKIE=7F...     nytimes
# 3240                                                        nytimes
# 3250                 U=8404820d8b2b85b7e285c2b1d4449fa0     nytimes
# 3264  IDE=AHWqTUmi4RVj356DXmEaC4Hzv7dq2CVyPkwHafkI0q...     nytimes
#
#       is_third_party  share_fp_cookie  share_tp_cookie  \
# 38              True             True            False
# 47              True            False             True
# 51              True             True             True
# 53              True             True            False
# 68              True            False             True
# 69              True             True             True
# 72              True             True            False
# 75              True             True            False
# 81              True             True            False
# 82              True             True            False
# 83              True             True            False
# 91              True             True            False
# 93              True             True            False
# 94              True             True            False
# 100             True            False             True
# 101             True             True            False
# 102             True             True            False
# 104             True             True             True
# 112             True             True            False
# 117             True             True            False
# 118             True             True            False
# 120             True             True            False
# 125             True             True            False
# 126             True             True            False
# 127             True             True            False
# 128             True             True            False
# 130             True            False             True
# 131             True            False             True
# 133             True            False             True
# 135             True            False             True
# ...              ...              ...              ...
# 2953            True            False             True
# 2958            True            False             True
# 2959            True            False             True
# 2963            True            False             True
# 2971            True            False             True
# 2975            True             True             True
# 2976            True             True             True
# 2992            True            False             True
# 3003            True            False             True
# 3010            True            False             True
# 3012            True            False             True
# 3170            True            False             True
# 3178            True            False             True
# 3180            True            False             True
# 3182            True             True             True
# 3198            True            False             True
# 3199            True            False             True
# 3206            True            False             True
# 3210            True            False             True
# 3216            True            False             True
# 3222            True            False             True
# 3226            True            False             True
# 3228            True             True             True
# 3229            True            False             True
# 3231            True            False             True
# 3232            True            False             True
# 3239            True            False             True
# 3240            True             True            False
# 3250            True            False             True
# 3264            True            False             True
#
#                                           referrer_host  is_diff_host  \
# 38                                        www.webmd.com          True
# 47                                        www.webmd.com          True
# 51                                        www.webmd.com          True
# 53                                        www.webmd.com          True
# 68                                        www.webmd.com          True
# 69                                        www.webmd.com          True
# 72                                        www.webmd.com          True
# 75                                        www.webmd.com          True
# 81                                        www.webmd.com          True
# 82                                        www.webmd.com          True
# 83                                        www.webmd.com          True
# 91                                        www.webmd.com          True
# 93                                        www.webmd.com          True
# 94                                        www.webmd.com          True
# 100                                       www.webmd.com          True
# 101                                       www.webmd.com          True
# 102                                       www.webmd.com          True
# 104                                       img.webmd.com          True
# 112                                       www.webmd.com          True
# 117                                       www.webmd.com          True
# 118                                       www.webmd.com          True
# 120                                       www.webmd.com          True
# 125                                       www.webmd.com          True
# 126                                       www.webmd.com          True
# 127                                       www.webmd.com          True
# 128                                       www.webmd.com          True
# 130                                contextual.media.net          True
# 131                                contextual.media.net          True
# 133                                contextual.media.net          True
# 135                                contextual.media.net          True
# ...                                                 ...           ...
# 2953                               contextual.media.net          True
# 2958                                    www.nytimes.com          True
# 2959                               contextual.media.net          True
# 2963                                  stags.bluekai.com          True
# 2971                               contextual.media.net          True
# 2975                                    www.nytimes.com          True
# 2976                                    www.nytimes.com          True
# 2992                             eus.rubiconproject.com          True
# 3003                             eus.rubiconproject.com          True
# 3010                                                             True
# 3012                             eus.rubiconproject.com          True
# 3170                             eus.rubiconproject.com          True
# 3178                                        u.openx.net          True
# 3180                                                             True
# 3182                             eus.rubiconproject.com          True
# 3198                                   ads.pubmatic.com          True
# 3199                                   ads.pubmatic.com          True
# 3206                                   ads.pubmatic.com          True
# 3210                                  stags.bluekai.com          True
# 3216                             eus.rubiconproject.com          True
# 3222                                   ads.pubmatic.com          True
# 3226                                   ads.pubmatic.com          True
# 3228                                   ads.pubmatic.com          True
# 3229                                   ads.pubmatic.com          True
# 3231                                   ads.pubmatic.com          True
# 3232                        googleads.g.doubleclick.net          True
# 3239                                   ads.pubmatic.com          True
# 3240  eb6611b34a41a87fee3f06cd0e100508.safeframe.goo...          True
# 3250                                   ads.pubmatic.com          True
# 3264                      pagead2.googlesyndication.com          True
#
#       referred_by_third
# 38                False
# 47                False
# 51                False
# 53                False
# 68                False
# 69                False
# 72                False
# 75                False
# 81                False
# 82                False
# 83                False
# 91                False
# 93                False
# 94                False
# 100               False
# 101               False
# 102               False
# 104               False
# 112               False
# 117               False
# 118               False
# 120               False
# 125               False
# 126               False
# 127               False
# 128               False
# 130                True
# 131                True
# 133                True
# 135                True
# ...                 ...
# 2953               True
# 2958              False
# 2959               True
# 2963               True
# 2971               True
# 2975              False
# 2976              False
# 2992               True
# 3003               True
# 3010               True
# 3012               True
# 3170               True
# 3178               True
# 3180               True
# 3182               True
# 3198               True
# 3199               True
# 3206               True
# 3210               True
# 3216               True
# 3222               True
# 3226               True
# 3228               True
# 3229               True
# 3231               True
# 3232               True
# 3239               True
# 3240               True
# 3250               True
# 3264               True
#
# [576 rows x 12 columns]

# %%
# http_requests_syncs[http_requests_syncs.share_fp_cookie].shape

# %%
# http_requests_syncs[http_requests_syncs.share_fp_cookie & http_requests_syncs.referred_by_third].shape

# %%
# http_requests_syncs[http_requests_syncs.share_tp_cookie].shape

# %%
# http_requests_syncs[http_requests_syncs.referred_by_third & http_requests_syncs.share_tp_cookie].shape

# %%
print(http_requests_syncs[http_requests_syncs.share_fp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.share_fp_cookie & http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie & http_requests_syncs.referred_by_third].shape[0])
# Out:
# 356
# 36
# 317
# 201

# %%
print(http_requests_syncs[http_requests_syncs.share_fp_cookie][http_requests_syncs.cookies==""].shape[0])
print(http_requests_syncs[http_requests_syncs.share_fp_cookie][http_requests_syncs.cookies==""][http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie][http_requests_syncs.cookies==""].shape[0])
print(http_requests_syncs[http_requests_syncs.share_tp_cookie][http_requests_syncs.cookies==""][http_requests_syncs.referred_by_third].shape[0])
# Out:
# 178
# 12
# 94
# 40
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
# http_requests_syncs[http_requests_syncs.is_diff_host & http_requests_syncs.share_tp_cookie].shape

# %%
# only index 3
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_fp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_fp_cookie][http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_tp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.share_tp_cookie][http_requests_syncs.referred_by_third].shape[0])
# Out:
# 10
# 4
# 44
# 35
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
# only index 3
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_fp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_fp_cookie][http_requests_syncs.referred_by_third].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_tp_cookie].shape[0])
print(http_requests_syncs[http_requests_syncs.visit_id==3][http_requests_syncs.cookies==""][http_requests_syncs.share_tp_cookie][http_requests_syncs.referred_by_third].shape[0])
# Out:
# 4
# 1
# 9
# 6
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
save_df_to_csv(http_requests_syncs, "cookie_syncs_" +file_name)
